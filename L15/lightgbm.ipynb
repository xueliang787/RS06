# %%
import pandas as pd
import numpy as np
import gc

# %%
train=pd.read_csv('train.csv')

# %%
train.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
test=pd.read_csv('test.csv')

# %%
test.columns
# Out:
# Index(['id', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
train.shape
# Out:
# (40428967, 24)

# %%
test.shape
# Out:
# (4577464, 23)

# %%
train = pd.concat([train, test], ignore_index=True, sort=False)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train=reduce_mem_usage(train)
# Out:
# Mem. usage decreased to 4463.83 Mb (45.8% reduction)

# %%
train['time']=pd.to_datetime(train['hour'],format='%y%m%d%H')
train['day']=train['time'].dt.day
train['hour']=train['time'].dt.hour

train['user']=train['device_id'].astype(str)+ '_' + train['device_ip'].astype(str)+ '_' +train['device_model'].astype(str)
train['app']=train['app_id'].astype(str)+ '_' + train['app_domain'].astype(str)+ '_' +train['app_category'].astype(str)
train['site']=train['site_id'].astype(str)+ '_' + train['site_domain'].astype(str)+ '_' +train['site_category'].astype(str)

# %%
train['day'].value_counts()
# Out:
# 22    5337126
# 28    5287222
# 31    4577464
# 30    4218938
# 21    4122995
# 23    3870752
# 26    3835892
# 29    3832608
# 25    3363122
# 24    3335302
# 27    3225010
# Name: day, dtype: int64

# %%
train.shape
# Out:
# (45006431, 29)

# %%
#选27-31日的数据训练
train = train[(train.day==27)|(train.day==28)|(train.day==29)|(train.day==30)|(train.day==31)]

# %%
train.shape
# Out:
# (21141242, 29)

# %%
train['day'].value_counts()
# Out:
# 28    5287222
# 31    4577464
# 30    4218938
# 29    3832608
# 27    3225010
# Name: day, dtype: int64

# %%
matrix=train
del train,test
gc.collect()
# Out:
# 5085

# %%
matrix['day'].value_counts()
# Out:
# 28    5287222
# 31    4577464
# 30    4218938
# 29    3832608
# 27    3225010
# Name: day, dtype: int64

# %%
matrix['device_ip_count']=matrix.groupby(['device_ip'])['device_ip'].transform('count')
matrix['device_id_count']=matrix.groupby(['device_id'])['device_id'].transform('count')
matrix['hourly_device_ip_count']=matrix.groupby(['device_ip','hour'])['device_ip'].transform('count')
matrix['hourly_device_id_count']=matrix.groupby(['device_id','hour'])['device_id'].transform('count')

matrix['user_count']=matrix.groupby(['user'])['user'].transform('count')
matrix['hourly_user_count']=matrix.groupby(['user','hour'])['user'].transform('count')
matrix['hourly_count']=matrix.groupby(['hour'])['hour'].transform('count')

matrix['app_count']=matrix.groupby(['app'])['app'].transform('count')
matrix['site_count']=matrix.groupby(['site'])['site'].transform('count')

matrix['hourly_app_count']=matrix.groupby(['app','hour'])['app'].transform('count')
matrix['hourly_site_count']=matrix.groupby(['site','hour'])['site'].transform('count')


matrix['C14_count']=matrix.groupby(['C14'])['C14'].transform('count')
matrix['C21_count']=matrix.groupby(['C21'])['C21'].transform('count')
matrix['C19_count']=matrix.groupby(['C19'])['C19'].transform('count')
matrix['C20_count']=matrix.groupby(['C20'])['C20'].transform('count')

# %%
matrix.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'time', 'day', 'user',
#        'app', 'site', 'device_ip_count', 'device_id_count',
#        'hourly_device_ip_count', 'hourly_device_id_count', 'user_count',
#        'hourly_user_count', 'hourly_count', 'app_count', 'site_count',
#        'hourly_app_count', 'hourly_site_count', 'C14_count', 'C21_count',
#        'C19_count', 'C20_count'],
#       dtype='object')

# %%
#对分类特征进行hash处理,某种程度上相当于label-encode
D=2**20
for feat in ['hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
       'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
       'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
       'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'time',  'user',
       'app', 'site']:
    
    matrix.loc[:,feat]=matrix.loc[:][feat].apply(lambda x:abs(hash((feat+'_'+str(x))))% D)

# %%
#测试时用

val=matrix[(matrix.day==30)] 
tra=matrix[(matrix.day==27)|(matrix.day==28)|(matrix.day==29)]
test=matrix[(matrix.day==31)]

del matrix
gc.collect()
# Out:
# 22

# %%
tra.shape
# Out:
# (12344840, 44)

# %%
val.shape
# Out:
# (4218938, 44)

# %%
test.shape
# Out:
# (4577464, 44)

# %%
tra.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'time', 'day', 'user',
#        'app', 'site', 'device_ip_count', 'device_id_count',
#        'hourly_device_ip_count', 'hourly_device_id_count', 'user_count',
#        'hourly_user_count', 'hourly_count', 'app_count', 'site_count',
#        'hourly_app_count', 'hourly_site_count', 'C14_count', 'C21_count',
#        'C19_count', 'C20_count'],
#       dtype='object')

# %%
features=[ 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
       'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
       'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
       'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'time', 'day', 'user',
       'app', 'site', 'device_ip_count', 'device_id_count',
       'hourly_device_ip_count', 'hourly_device_id_count', 'user_count',
       'hourly_user_count', 'hourly_count', 'app_count', 'site_count',
       'hourly_app_count', 'hourly_site_count', 'C14_count', 'C21_count',
       'C19_count', 'C20_count']

# %%
#测试时用
y_val=val['click']
x_val=val[features]
y_train=tra['click']
x_train=tra[features]
x_test=test[features]

# %%
import lightgbm as lgb

lgb_params = {
    'n_estimators' : 2000,
    'learning_rate' : 0.02,
    'colsample_bytree' : 0.3,
    'subsample' : 0.7,
    'subsample_freq' : 2,
    'num_leaves' : 16,
    'seed' : 99
}

lgb_model = lgb.LGBMClassifier(**lgb_params)

# %%
lgb_model.fit(x_train, y_train, eval_set=[(x_train, y_train),(x_val, y_val)],  eval_metric='logloss',verbose=True,early_stopping_rounds=50)
# Out:
# [1]	training's binary_logloss: 0.440442	valid_1's binary_logloss: 0.453775
# Training until validation scores don't improve for 50 rounds
# [2]	training's binary_logloss: 0.439232	valid_1's binary_logloss: 0.452561
# [3]	training's binary_logloss: 0.438123	valid_1's binary_logloss: 0.451397
# [4]	training's binary_logloss: 0.437123	valid_1's binary_logloss: 0.450689
# [5]	training's binary_logloss: 0.436066	valid_1's binary_logloss: 0.449724
# [6]	training's binary_logloss: 0.435	valid_1's binary_logloss: 0.448944
# [7]	training's binary_logloss: 0.434014	valid_1's binary_logloss: 0.447971
# [8]	training's binary_logloss: 0.43292	valid_1's binary_logloss: 0.446842
# [9]	training's binary_logloss: 0.431907	valid_1's binary_logloss: 0.445873
# [10]	training's binary_logloss: 0.431034	valid_1's binary_logloss: 0.445234
# [11]	training's binary_logloss: 0.43019	valid_1's binary_logloss: 0.444531
# [12]	training's binary_logloss: 0.42939	valid_1's binary_logloss: 0.44381
# [13]	training's binary_logloss: 0.428698	valid_1's binary_logloss: 0.443197
# [14]	training's binary_logloss: 0.427893	valid_1's binary_logloss: 0.442304
# [15]	training's binary_logloss: 0.427231	valid_1's binary_logloss: 0.441641
# [16]	training's binary_logloss: 0.426494	valid_1's binary_logloss: 0.440946
# [17]	training's binary_logloss: 0.425694	valid_1's binary_logloss: 0.440124
# [18]	training's binary_logloss: 0.425036	valid_1's binary_logloss: 0.439373
# [19]	training's binary_logloss: 0.424363	valid_1's binary_logloss: 0.438783
# [20]	training's binary_logloss: 0.423755	valid_1's binary_logloss: 0.438118
# [21]	training's binary_logloss: 0.423112	valid_1's binary_logloss: 0.437472
# [22]	training's binary_logloss: 0.422434	valid_1's binary_logloss: 0.43681
# [23]	training's binary_logloss: 0.421844	valid_1's binary_logloss: 0.436262
# [24]	training's binary_logloss: 0.421256	valid_1's binary_logloss: 0.435789
# [25]	training's binary_logloss: 0.420721	valid_1's binary_logloss: 0.435218
# [26]	training's binary_logloss: 0.420205	valid_1's binary_logloss: 0.434851
# [27]	training's binary_logloss: 0.419659	valid_1's binary_logloss: 0.434234
# [28]	training's binary_logloss: 0.419006	valid_1's binary_logloss: 0.433645
# [29]	training's binary_logloss: 0.418444	valid_1's binary_logloss: 0.433227
# [30]	training's binary_logloss: 0.41791	valid_1's binary_logloss: 0.432888
# [31]	training's binary_logloss: 0.417444	valid_1's binary_logloss: 0.432377
# [32]	training's binary_logloss: 0.416935	valid_1's binary_logloss: 0.431984
# [33]	training's binary_logloss: 0.416453	valid_1's binary_logloss: 0.431508
# [34]	training's binary_logloss: 0.416025	valid_1's binary_logloss: 0.431237
# [35]	training's binary_logloss: 0.415542	valid_1's binary_logloss: 0.430782
# [36]	training's binary_logloss: 0.415221	valid_1's binary_logloss: 0.430424
# [37]	training's binary_logloss: 0.414755	valid_1's binary_logloss: 0.430008
# [38]	training's binary_logloss: 0.414379	valid_1's binary_logloss: 0.429708
# [39]	training's binary_logloss: 0.414007	valid_1's binary_logloss: 0.429341
# [40]	training's binary_logloss: 0.413581	valid_1's binary_logloss: 0.429109
# [41]	training's binary_logloss: 0.413232	valid_1's binary_logloss: 0.428761
# [42]	training's binary_logloss: 0.412905	valid_1's binary_logloss: 0.428459
# [43]	training's binary_logloss: 0.41248	valid_1's binary_logloss: 0.428067
# [44]	training's binary_logloss: 0.412157	valid_1's binary_logloss: 0.42776
# [45]	training's binary_logloss: 0.411762	valid_1's binary_logloss: 0.427512
# [46]	training's binary_logloss: 0.411413	valid_1's binary_logloss: 0.42731
# [47]	training's binary_logloss: 0.411113	valid_1's binary_logloss: 0.426997
# [48]	training's binary_logloss: 0.410776	valid_1's binary_logloss: 0.426674
# [49]	training's binary_logloss: 0.410429	valid_1's binary_logloss: 0.426481
# [50]	training's binary_logloss: 0.410142	valid_1's binary_logloss: 0.426254
# [51]	training's binary_logloss: 0.409816	valid_1's binary_logloss: 0.425936
# [52]	training's binary_logloss: 0.409541	valid_1's binary_logloss: 0.425752
# [53]	training's binary_logloss: 0.409235	valid_1's binary_logloss: 0.425467
# [54]	training's binary_logloss: 0.408987	valid_1's binary_logloss: 0.425239
# [55]	training's binary_logloss: 0.40876	valid_1's binary_logloss: 0.425021
# [56]	training's binary_logloss: 0.408549	valid_1's binary_logloss: 0.424858
# [57]	training's binary_logloss: 0.408264	valid_1's binary_logloss: 0.424648
# [58]	training's binary_logloss: 0.408036	valid_1's binary_logloss: 0.424539
# [59]	training's binary_logloss: 0.407774	valid_1's binary_logloss: 0.424358
# [60]	training's binary_logloss: 0.407424	valid_1's binary_logloss: 0.424049
# [61]	training's binary_logloss: 0.407187	valid_1's binary_logloss: 0.423881
# [62]	training's binary_logloss: 0.406904	valid_1's binary_logloss: 0.423732
# [63]	training's binary_logloss: 0.40667	valid_1's binary_logloss: 0.423594
# [64]	training's binary_logloss: 0.406433	valid_1's binary_logloss: 0.423382
# [65]	training's binary_logloss: 0.406188	valid_1's binary_logloss: 0.423126
# [66]	training's binary_logloss: 0.406008	valid_1's binary_logloss: 0.423004
# [67]	training's binary_logloss: 0.405858	valid_1's binary_logloss: 0.422816
# [68]	training's binary_logloss: 0.405616	valid_1's binary_logloss: 0.422595
# [69]	training's binary_logloss: 0.405401	valid_1's binary_logloss: 0.422425
# [70]	training's binary_logloss: 0.405196	valid_1's binary_logloss: 0.422306
# [71]	training's binary_logloss: 0.404972	valid_1's binary_logloss: 0.422111
# [72]	training's binary_logloss: 0.40477	valid_1's binary_logloss: 0.42197
# [73]	training's binary_logloss: 0.404574	valid_1's binary_logloss: 0.421771
# [74]	training's binary_logloss: 0.40438	valid_1's binary_logloss: 0.421597
# [75]	training's binary_logloss: 0.404191	valid_1's binary_logloss: 0.421403
# [76]	training's binary_logloss: 0.404006	valid_1's binary_logloss: 0.421212
# [77]	training's binary_logloss: 0.403749	valid_1's binary_logloss: 0.420971
# [78]	training's binary_logloss: 0.40356	valid_1's binary_logloss: 0.420792
# [79]	training's binary_logloss: 0.403402	valid_1's binary_logloss: 0.420672
# [80]	training's binary_logloss: 0.403231	valid_1's binary_logloss: 0.420559
# [81]	training's binary_logloss: 0.403032	valid_1's binary_logloss: 0.420442
# [82]	training's binary_logloss: 0.402843	valid_1's binary_logloss: 0.420327
# [83]	training's binary_logloss: 0.402623	valid_1's binary_logloss: 0.420111
# [84]	training's binary_logloss: 0.402446	valid_1's binary_logloss: 0.420039
# [85]	training's binary_logloss: 0.402235	valid_1's binary_logloss: 0.419883
# [86]	training's binary_logloss: 0.402078	valid_1's binary_logloss: 0.419755
# [87]	training's binary_logloss: 0.401898	valid_1's binary_logloss: 0.419648
# [88]	training's binary_logloss: 0.401765	valid_1's binary_logloss: 0.419571
# [89]	training's binary_logloss: 0.401664	valid_1's binary_logloss: 0.419467
# [90]	training's binary_logloss: 0.401534	valid_1's binary_logloss: 0.419331
# [91]	training's binary_logloss: 0.401399	valid_1's binary_logloss: 0.419213
# [92]	training's binary_logloss: 0.401246	valid_1's binary_logloss: 0.419066
# [93]	training's binary_logloss: 0.401095	valid_1's binary_logloss: 0.418945
# [94]	training's binary_logloss: 0.400912	valid_1's binary_logloss: 0.418822
# [95]	training's binary_logloss: 0.400805	valid_1's binary_logloss: 0.418701
# [96]	training's binary_logloss: 0.40065	valid_1's binary_logloss: 0.418601
# [97]	training's binary_logloss: 0.400536	valid_1's binary_logloss: 0.418511
# [98]	training's binary_logloss: 0.400388	valid_1's binary_logloss: 0.418413
# [99]	training's binary_logloss: 0.400269	valid_1's binary_logloss: 0.418355
# [100]	training's binary_logloss: 0.400124	valid_1's binary_logloss: 0.41823
# [101]	training's binary_logloss: 0.40001	valid_1's binary_logloss: 0.418156
# [102]	training's binary_logloss: 0.399919	valid_1's binary_logloss: 0.418111
# [103]	training's binary_logloss: 0.399791	valid_1's binary_logloss: 0.418018
# [104]	training's binary_logloss: 0.399689	valid_1's binary_logloss: 0.417904
# [105]	training's binary_logloss: 0.39956	valid_1's binary_logloss: 0.417783
# [106]	training's binary_logloss: 0.399467	valid_1's binary_logloss: 0.417691
# [107]	training's binary_logloss: 0.399359	valid_1's binary_logloss: 0.417645
# [108]	training's binary_logloss: 0.39924	valid_1's binary_logloss: 0.417554
# [109]	training's binary_logloss: 0.399134	valid_1's binary_logloss: 0.417469
# [110]	training's binary_logloss: 0.39904	valid_1's binary_logloss: 0.417406
# [111]	training's binary_logloss: 0.398945	valid_1's binary_logloss: 0.417316
# [112]	training's binary_logloss: 0.398851	valid_1's binary_logloss: 0.417229
# [113]	training's binary_logloss: 0.398752	valid_1's binary_logloss: 0.417176
# [114]	training's binary_logloss: 0.398655	valid_1's binary_logloss: 0.417117
# [115]	training's binary_logloss: 0.398536	valid_1's binary_logloss: 0.417029
# [116]	training's binary_logloss: 0.398416	valid_1's binary_logloss: 0.416934
# [117]	training's binary_logloss: 0.398331	valid_1's binary_logloss: 0.416889
# [118]	training's binary_logloss: 0.398227	valid_1's binary_logloss: 0.416821
# [119]	training's binary_logloss: 0.398133	valid_1's binary_logloss: 0.416712
# [120]	training's binary_logloss: 0.398013	valid_1's binary_logloss: 0.416613
# [121]	training's binary_logloss: 0.397914	valid_1's binary_logloss: 0.416543
# [122]	training's binary_logloss: 0.397829	valid_1's binary_logloss: 0.416476
# [123]	training's binary_logloss: 0.397716	valid_1's binary_logloss: 0.416408
# [124]	training's binary_logloss: 0.397625	valid_1's binary_logloss: 0.41632
# [125]	training's binary_logloss: 0.397511	valid_1's binary_logloss: 0.416243
# [126]	training's binary_logloss: 0.397422	valid_1's binary_logloss: 0.41621
# [127]	training's binary_logloss: 0.397339	valid_1's binary_logloss: 0.416149
# [128]	training's binary_logloss: 0.397244	valid_1's binary_logloss: 0.416079
# [129]	training's binary_logloss: 0.397176	valid_1's binary_logloss: 0.416034
# [130]	training's binary_logloss: 0.397101	valid_1's binary_logloss: 0.415966
# [131]	training's binary_logloss: 0.397022	valid_1's binary_logloss: 0.415889
# [132]	training's binary_logloss: 0.396937	valid_1's binary_logloss: 0.41584
# [133]	training's binary_logloss: 0.396858	valid_1's binary_logloss: 0.415766
# [134]	training's binary_logloss: 0.396761	valid_1's binary_logloss: 0.415689
# [135]	training's binary_logloss: 0.39668	valid_1's binary_logloss: 0.415616
# [136]	training's binary_logloss: 0.396556	valid_1's binary_logloss: 0.4155
# [137]	training's binary_logloss: 0.396479	valid_1's binary_logloss: 0.415433
# [138]	training's binary_logloss: 0.396366	valid_1's binary_logloss: 0.41535
# [139]	training's binary_logloss: 0.396285	valid_1's binary_logloss: 0.415339
# [140]	training's binary_logloss: 0.396219	valid_1's binary_logloss: 0.415291
# [141]	training's binary_logloss: 0.396149	valid_1's binary_logloss: 0.415222
# [142]	training's binary_logloss: 0.396083	valid_1's binary_logloss: 0.41518
# [143]	training's binary_logloss: 0.395984	valid_1's binary_logloss: 0.415124
# [144]	training's binary_logloss: 0.395917	valid_1's binary_logloss: 0.415053
# [145]	training's binary_logloss: 0.39583	valid_1's binary_logloss: 0.414969
# [146]	training's binary_logloss: 0.395756	valid_1's binary_logloss: 0.414899
# [147]	training's binary_logloss: 0.395674	valid_1's binary_logloss: 0.41485
# [148]	training's binary_logloss: 0.395598	valid_1's binary_logloss: 0.414779
# [149]	training's binary_logloss: 0.395522	valid_1's binary_logloss: 0.414751
# [150]	training's binary_logloss: 0.39545	valid_1's binary_logloss: 0.414695
# [151]	training's binary_logloss: 0.395381	valid_1's binary_logloss: 0.414639
# [152]	training's binary_logloss: 0.395328	valid_1's binary_logloss: 0.41461
# [153]	training's binary_logloss: 0.395271	valid_1's binary_logloss: 0.414567
# [154]	training's binary_logloss: 0.395198	valid_1's binary_logloss: 0.414545
# [155]	training's binary_logloss: 0.395144	valid_1's binary_logloss: 0.414514
# [156]	training's binary_logloss: 0.395079	valid_1's binary_logloss: 0.414446
# [157]	training's binary_logloss: 0.395025	valid_1's binary_logloss: 0.414413
# [158]	training's binary_logloss: 0.394968	valid_1's binary_logloss: 0.414369
# [159]	training's binary_logloss: 0.394914	valid_1's binary_logloss: 0.414312
# [160]	training's binary_logloss: 0.394847	valid_1's binary_logloss: 0.41428
# [161]	training's binary_logloss: 0.394788	valid_1's binary_logloss: 0.414214
# [162]	training's binary_logloss: 0.39473	valid_1's binary_logloss: 0.414142
# [163]	training's binary_logloss: 0.394651	valid_1's binary_logloss: 0.414065
# [164]	training's binary_logloss: 0.394604	valid_1's binary_logloss: 0.414029
# [165]	training's binary_logloss: 0.394545	valid_1's binary_logloss: 0.413979
# [166]	training's binary_logloss: 0.394503	valid_1's binary_logloss: 0.413945
# [167]	training's binary_logloss: 0.394451	valid_1's binary_logloss: 0.413897
# [168]	training's binary_logloss: 0.394411	valid_1's binary_logloss: 0.413865
# [169]	training's binary_logloss: 0.394367	valid_1's binary_logloss: 0.413839
# [170]	training's binary_logloss: 0.394306	valid_1's binary_logloss: 0.413783
# [171]	training's binary_logloss: 0.39426	valid_1's binary_logloss: 0.413737
# [172]	training's binary_logloss: 0.394192	valid_1's binary_logloss: 0.413744
# [173]	training's binary_logloss: 0.394146	valid_1's binary_logloss: 0.413725
# [174]	training's binary_logloss: 0.394095	valid_1's binary_logloss: 0.413691
# [175]	training's binary_logloss: 0.394034	valid_1's binary_logloss: 0.413648
# [176]	training's binary_logloss: 0.393999	valid_1's binary_logloss: 0.413616
# [177]	training's binary_logloss: 0.393953	valid_1's binary_logloss: 0.413566
# [178]	training's binary_logloss: 0.393899	valid_1's binary_logloss: 0.413531
# [179]	training's binary_logloss: 0.393816	valid_1's binary_logloss: 0.413462
# [180]	training's binary_logloss: 0.393768	valid_1's binary_logloss: 0.413408
# [181]	training's binary_logloss: 0.393697	valid_1's binary_logloss: 0.413359
# [182]	training's binary_logloss: 0.393637	valid_1's binary_logloss: 0.413333
# [183]	training's binary_logloss: 0.393591	valid_1's binary_logloss: 0.413304
# [184]	training's binary_logloss: 0.393551	valid_1's binary_logloss: 0.413268
# [185]	training's binary_logloss: 0.393501	valid_1's binary_logloss: 0.413223
# [186]	training's binary_logloss: 0.393421	valid_1's binary_logloss: 0.413168
# [187]	training's binary_logloss: 0.393368	valid_1's binary_logloss: 0.413134
# [188]	training's binary_logloss: 0.393323	valid_1's binary_logloss: 0.413119
# [189]	training's binary_logloss: 0.393278	valid_1's binary_logloss: 0.413099
# [190]	training's binary_logloss: 0.393233	valid_1's binary_logloss: 0.413078
# [191]	training's binary_logloss: 0.393182	valid_1's binary_logloss: 0.413003
# [192]	training's binary_logloss: 0.393143	valid_1's binary_logloss: 0.41297
# [193]	training's binary_logloss: 0.393091	valid_1's binary_logloss: 0.412918
# [194]	training's binary_logloss: 0.393037	valid_1's binary_logloss: 0.412908
# [195]	training's binary_logloss: 0.392995	valid_1's binary_logloss: 0.412856
# [196]	training's binary_logloss: 0.39295	valid_1's binary_logloss: 0.412814
# [197]	training's binary_logloss: 0.392895	valid_1's binary_logloss: 0.412784
# [198]	training's binary_logloss: 0.392827	valid_1's binary_logloss: 0.412747
# [199]	training's binary_logloss: 0.392774	valid_1's binary_logloss: 0.412731
# [200]	training's binary_logloss: 0.392738	valid_1's binary_logloss: 0.412702
# [201]	training's binary_logloss: 0.392671	valid_1's binary_logloss: 0.412648
# [202]	training's binary_logloss: 0.392635	valid_1's binary_logloss: 0.412609
# [203]	training's binary_logloss: 0.392566	valid_1's binary_logloss: 0.412549
# [204]	training's binary_logloss: 0.392524	valid_1's binary_logloss: 0.412538
# [205]	training's binary_logloss: 0.392482	valid_1's binary_logloss: 0.412488
# [206]	training's binary_logloss: 0.392435	valid_1's binary_logloss: 0.412428
# [207]	training's binary_logloss: 0.392383	valid_1's binary_logloss: 0.412389
# [208]	training's binary_logloss: 0.392342	valid_1's binary_logloss: 0.412356
# [209]	training's binary_logloss: 0.392297	valid_1's binary_logloss: 0.412344
# [210]	training's binary_logloss: 0.392264	valid_1's binary_logloss: 0.412317
# [211]	training's binary_logloss: 0.392207	valid_1's binary_logloss: 0.412261
# [212]	training's binary_logloss: 0.392171	valid_1's binary_logloss: 0.412213
# [213]	training's binary_logloss: 0.392122	valid_1's binary_logloss: 0.412178
# [214]	training's binary_logloss: 0.39209	valid_1's binary_logloss: 0.41214
# [215]	training's binary_logloss: 0.392037	valid_1's binary_logloss: 0.412102
# [216]	training's binary_logloss: 0.391997	valid_1's binary_logloss: 0.412117
# [217]	training's binary_logloss: 0.391967	valid_1's binary_logloss: 0.412078
# [218]	training's binary_logloss: 0.391911	valid_1's binary_logloss: 0.412031
# [219]	training's binary_logloss: 0.391875	valid_1's binary_logloss: 0.411999
# [220]	training's binary_logloss: 0.391836	valid_1's binary_logloss: 0.41197
# [221]	training's binary_logloss: 0.391792	valid_1's binary_logloss: 0.411909
# [222]	training's binary_logloss: 0.391758	valid_1's binary_logloss: 0.411875
# [223]	training's binary_logloss: 0.391717	valid_1's binary_logloss: 0.411847
# [224]	training's binary_logloss: 0.391681	valid_1's binary_logloss: 0.411807
# [225]	training's binary_logloss: 0.391652	valid_1's binary_logloss: 0.411788
# [226]	training's binary_logloss: 0.39161	valid_1's binary_logloss: 0.411742
# [227]	training's binary_logloss: 0.391578	valid_1's binary_logloss: 0.411719
# [228]	training's binary_logloss: 0.39153	valid_1's binary_logloss: 0.411704
# [229]	training's binary_logloss: 0.391499	valid_1's binary_logloss: 0.411685
# [230]	training's binary_logloss: 0.391474	valid_1's binary_logloss: 0.411671
# [231]	training's binary_logloss: 0.391437	valid_1's binary_logloss: 0.411626
# [232]	training's binary_logloss: 0.391398	valid_1's binary_logloss: 0.411597
# [233]	training's binary_logloss: 0.391366	valid_1's binary_logloss: 0.411577
# [234]	training's binary_logloss: 0.391334	valid_1's binary_logloss: 0.41153
# [235]	training's binary_logloss: 0.391293	valid_1's binary_logloss: 0.411498
# [236]	training's binary_logloss: 0.391254	valid_1's binary_logloss: 0.411461
# [237]	training's binary_logloss: 0.391217	valid_1's binary_logloss: 0.411438
# [238]	training's binary_logloss: 0.391187	valid_1's binary_logloss: 0.411412
# [239]	training's binary_logloss: 0.39116	valid_1's binary_logloss: 0.411387
# [240]	training's binary_logloss: 0.391127	valid_1's binary_logloss: 0.411348
# [241]	training's binary_logloss: 0.391081	valid_1's binary_logloss: 0.411369
# [242]	training's binary_logloss: 0.391042	valid_1's binary_logloss: 0.411331
# [243]	training's binary_logloss: 0.391004	valid_1's binary_logloss: 0.4113
# [244]	training's binary_logloss: 0.390979	valid_1's binary_logloss: 0.411265
# [245]	training's binary_logloss: 0.390947	valid_1's binary_logloss: 0.411229
# [246]	training's binary_logloss: 0.390917	valid_1's binary_logloss: 0.4112
# [247]	training's binary_logloss: 0.390893	valid_1's binary_logloss: 0.41118
# [248]	training's binary_logloss: 0.390845	valid_1's binary_logloss: 0.411145
# [249]	training's binary_logloss: 0.390816	valid_1's binary_logloss: 0.411137
# [250]	training's binary_logloss: 0.390781	valid_1's binary_logloss: 0.411131
# [251]	training's binary_logloss: 0.390739	valid_1's binary_logloss: 0.41116
# [252]	training's binary_logloss: 0.390681	valid_1's binary_logloss: 0.41112
# [253]	training's binary_logloss: 0.390656	valid_1's binary_logloss: 0.411105
# [254]	training's binary_logloss: 0.390623	valid_1's binary_logloss: 0.411073
# [255]	training's binary_logloss: 0.390592	valid_1's binary_logloss: 0.411053
# [256]	training's binary_logloss: 0.390569	valid_1's binary_logloss: 0.411033
# [257]	training's binary_logloss: 0.390535	valid_1's binary_logloss: 0.411016
# [258]	training's binary_logloss: 0.390506	valid_1's binary_logloss: 0.410991
# [259]	training's binary_logloss: 0.390469	valid_1's binary_logloss: 0.410959
# [260]	training's binary_logloss: 0.39044	valid_1's binary_logloss: 0.410923
# [261]	training's binary_logloss: 0.39041	valid_1's binary_logloss: 0.410892
# [262]	training's binary_logloss: 0.390383	valid_1's binary_logloss: 0.410875
# [263]	training's binary_logloss: 0.390346	valid_1's binary_logloss: 0.410901
# [264]	training's binary_logloss: 0.39031	valid_1's binary_logloss: 0.410858
# [265]	training's binary_logloss: 0.390283	valid_1's binary_logloss: 0.410839
# [266]	training's binary_logloss: 0.390258	valid_1's binary_logloss: 0.410808
# [267]	training's binary_logloss: 0.390229	valid_1's binary_logloss: 0.410781
# [268]	training's binary_logloss: 0.390192	valid_1's binary_logloss: 0.410762
# [269]	training's binary_logloss: 0.390159	valid_1's binary_logloss: 0.410732
# [270]	training's binary_logloss: 0.390134	valid_1's binary_logloss: 0.410703
# [271]	training's binary_logloss: 0.390109	valid_1's binary_logloss: 0.410675
# [272]	training's binary_logloss: 0.390082	valid_1's binary_logloss: 0.410664
# [273]	training's binary_logloss: 0.390058	valid_1's binary_logloss: 0.410634
# [274]	training's binary_logloss: 0.390031	valid_1's binary_logloss: 0.410613
# [275]	training's binary_logloss: 0.390004	valid_1's binary_logloss: 0.410571
# [276]	training's binary_logloss: 0.389981	valid_1's binary_logloss: 0.410554
# [277]	training's binary_logloss: 0.389961	valid_1's binary_logloss: 0.410536
# [278]	training's binary_logloss: 0.389937	valid_1's binary_logloss: 0.410497
# [279]	training's binary_logloss: 0.389903	valid_1's binary_logloss: 0.410477
# [280]	training's binary_logloss: 0.389881	valid_1's binary_logloss: 0.41047
# [281]	training's binary_logloss: 0.389838	valid_1's binary_logloss: 0.41044
# [282]	training's binary_logloss: 0.389817	valid_1's binary_logloss: 0.410429
# [283]	training's binary_logloss: 0.389785	valid_1's binary_logloss: 0.410406
# [284]	training's binary_logloss: 0.389758	valid_1's binary_logloss: 0.410379
# [285]	training's binary_logloss: 0.38973	valid_1's binary_logloss: 0.410364
# [286]	training's binary_logloss: 0.389706	valid_1's binary_logloss: 0.410344
# [287]	training's binary_logloss: 0.389674	valid_1's binary_logloss: 0.410323
# [288]	training's binary_logloss: 0.389655	valid_1's binary_logloss: 0.410304
# [289]	training's binary_logloss: 0.389628	valid_1's binary_logloss: 0.410281
# [290]	training's binary_logloss: 0.389592	valid_1's binary_logloss: 0.410252
# [291]	training's binary_logloss: 0.389567	valid_1's binary_logloss: 0.410224
# [292]	training's binary_logloss: 0.389536	valid_1's binary_logloss: 0.410212
# [293]	training's binary_logloss: 0.389508	valid_1's binary_logloss: 0.410199
# [294]	training's binary_logloss: 0.389484	valid_1's binary_logloss: 0.410173
# [295]	training's binary_logloss: 0.389456	valid_1's binary_logloss: 0.410153
# [296]	training's binary_logloss: 0.389432	valid_1's binary_logloss: 0.41014
# [297]	training's binary_logloss: 0.389415	valid_1's binary_logloss: 0.410119
# [298]	training's binary_logloss: 0.389386	valid_1's binary_logloss: 0.410105
# [299]	training's binary_logloss: 0.389366	valid_1's binary_logloss: 0.410081
# [300]	training's binary_logloss: 0.389343	valid_1's binary_logloss: 0.410055
# [301]	training's binary_logloss: 0.38932	valid_1's binary_logloss: 0.410038
# [302]	training's binary_logloss: 0.3893	valid_1's binary_logloss: 0.410028
# [303]	training's binary_logloss: 0.389272	valid_1's binary_logloss: 0.410061
# [304]	training's binary_logloss: 0.389242	valid_1's binary_logloss: 0.41008
# [305]	training's binary_logloss: 0.38922	valid_1's binary_logloss: 0.410058
# [306]	training's binary_logloss: 0.389193	valid_1's binary_logloss: 0.410038
# [307]	training's binary_logloss: 0.38917	valid_1's binary_logloss: 0.410016
# [308]	training's binary_logloss: 0.389145	valid_1's binary_logloss: 0.409994
# [309]	training's binary_logloss: 0.389104	valid_1's binary_logloss: 0.409959
# [310]	training's binary_logloss: 0.389083	valid_1's binary_logloss: 0.409945
# [311]	training's binary_logloss: 0.389065	valid_1's binary_logloss: 0.409923
# [312]	training's binary_logloss: 0.389041	valid_1's binary_logloss: 0.409902
# [313]	training's binary_logloss: 0.389012	valid_1's binary_logloss: 0.409875
# [314]	training's binary_logloss: 0.388983	valid_1's binary_logloss: 0.40986
# [315]	training's binary_logloss: 0.388959	valid_1's binary_logloss: 0.409829
# [316]	training's binary_logloss: 0.388934	valid_1's binary_logloss: 0.409805
# [317]	training's binary_logloss: 0.388913	valid_1's binary_logloss: 0.409792
# [318]	training's binary_logloss: 0.388892	valid_1's binary_logloss: 0.409777
# [319]	training's binary_logloss: 0.388875	valid_1's binary_logloss: 0.409764
# [320]	training's binary_logloss: 0.388851	valid_1's binary_logloss: 0.40973
# [321]	training's binary_logloss: 0.388823	valid_1's binary_logloss: 0.409712
# [322]	training's binary_logloss: 0.388799	valid_1's binary_logloss: 0.409689
# [323]	training's binary_logloss: 0.388771	valid_1's binary_logloss: 0.409669
# [324]	training's binary_logloss: 0.388745	valid_1's binary_logloss: 0.409648
# [325]	training's binary_logloss: 0.388725	valid_1's binary_logloss: 0.409621
# [326]	training's binary_logloss: 0.388707	valid_1's binary_logloss: 0.409619
# [327]	training's binary_logloss: 0.388687	valid_1's binary_logloss: 0.409594
# [328]	training's binary_logloss: 0.388668	valid_1's binary_logloss: 0.409579
# [329]	training's binary_logloss: 0.388645	valid_1's binary_logloss: 0.409571
# [330]	training's binary_logloss: 0.388617	valid_1's binary_logloss: 0.409541
# [331]	training's binary_logloss: 0.3886	valid_1's binary_logloss: 0.409528
# [332]	training's binary_logloss: 0.388578	valid_1's binary_logloss: 0.40951
# [333]	training's binary_logloss: 0.38856	valid_1's binary_logloss: 0.409494
# [334]	training's binary_logloss: 0.388532	valid_1's binary_logloss: 0.409489
# [335]	training's binary_logloss: 0.388507	valid_1's binary_logloss: 0.409464
# [336]	training's binary_logloss: 0.388483	valid_1's binary_logloss: 0.409454
# [337]	training's binary_logloss: 0.388464	valid_1's binary_logloss: 0.409451
# [338]	training's binary_logloss: 0.388437	valid_1's binary_logloss: 0.409424
# [339]	training's binary_logloss: 0.388422	valid_1's binary_logloss: 0.409407
# [340]	training's binary_logloss: 0.388399	valid_1's binary_logloss: 0.409401
# [341]	training's binary_logloss: 0.388385	valid_1's binary_logloss: 0.4094
# [342]	training's binary_logloss: 0.388371	valid_1's binary_logloss: 0.409381
# [343]	training's binary_logloss: 0.388337	valid_1's binary_logloss: 0.409339
# [344]	training's binary_logloss: 0.388318	valid_1's binary_logloss: 0.409332
# [345]	training's binary_logloss: 0.388297	valid_1's binary_logloss: 0.409319
# [346]	training's binary_logloss: 0.388282	valid_1's binary_logloss: 0.409304
# [347]	training's binary_logloss: 0.388269	valid_1's binary_logloss: 0.409289
# [348]	training's binary_logloss: 0.388244	valid_1's binary_logloss: 0.409282
# [349]	training's binary_logloss: 0.388221	valid_1's binary_logloss: 0.409272
# [350]	training's binary_logloss: 0.388192	valid_1's binary_logloss: 0.409236
# [351]	training's binary_logloss: 0.388165	valid_1's binary_logloss: 0.409209
# [352]	training's binary_logloss: 0.388139	valid_1's binary_logloss: 0.40919
# [353]	training's binary_logloss: 0.388113	valid_1's binary_logloss: 0.409162
# [354]	training's binary_logloss: 0.388083	valid_1's binary_logloss: 0.409133
# [355]	training's binary_logloss: 0.388065	valid_1's binary_logloss: 0.409112
# [356]	training's binary_logloss: 0.388028	valid_1's binary_logloss: 0.409082
# [357]	training's binary_logloss: 0.388	valid_1's binary_logloss: 0.409074
# [358]	training's binary_logloss: 0.38798	valid_1's binary_logloss: 0.409063
# [359]	training's binary_logloss: 0.387955	valid_1's binary_logloss: 0.409039
# [360]	training's binary_logloss: 0.387931	valid_1's binary_logloss: 0.409014
# [361]	training's binary_logloss: 0.38791	valid_1's binary_logloss: 0.408999
# [362]	training's binary_logloss: 0.387892	valid_1's binary_logloss: 0.409002
# [363]	training's binary_logloss: 0.387871	valid_1's binary_logloss: 0.408996
# [364]	training's binary_logloss: 0.387854	valid_1's binary_logloss: 0.408982
# [365]	training's binary_logloss: 0.387829	valid_1's binary_logloss: 0.408969
# [366]	training's binary_logloss: 0.387811	valid_1's binary_logloss: 0.408951
# [367]	training's binary_logloss: 0.387797	valid_1's binary_logloss: 0.40893
# [368]	training's binary_logloss: 0.387771	valid_1's binary_logloss: 0.408905
# [369]	training's binary_logloss: 0.387753	valid_1's binary_logloss: 0.408888
# [370]	training's binary_logloss: 0.387721	valid_1's binary_logloss: 0.408854
# [371]	training's binary_logloss: 0.387702	valid_1's binary_logloss: 0.408849
# [372]	training's binary_logloss: 0.38769	valid_1's binary_logloss: 0.408835
# [373]	training's binary_logloss: 0.387672	valid_1's binary_logloss: 0.408816
# [374]	training's binary_logloss: 0.387645	valid_1's binary_logloss: 0.408797
# [375]	training's binary_logloss: 0.387619	valid_1's binary_logloss: 0.40878
# [376]	training's binary_logloss: 0.387605	valid_1's binary_logloss: 0.408767
# [377]	training's binary_logloss: 0.387591	valid_1's binary_logloss: 0.408744
# [378]	training's binary_logloss: 0.387562	valid_1's binary_logloss: 0.408728
# [379]	training's binary_logloss: 0.387541	valid_1's binary_logloss: 0.408718
# [380]	training's binary_logloss: 0.38752	valid_1's binary_logloss: 0.408705
# [381]	training's binary_logloss: 0.387505	valid_1's binary_logloss: 0.408685
# [382]	training's binary_logloss: 0.387468	valid_1's binary_logloss: 0.40865
# [383]	training's binary_logloss: 0.387453	valid_1's binary_logloss: 0.408644
# [384]	training's binary_logloss: 0.387433	valid_1's binary_logloss: 0.408625
# [385]	training's binary_logloss: 0.387414	valid_1's binary_logloss: 0.408604
# [386]	training's binary_logloss: 0.387393	valid_1's binary_logloss: 0.408611
# [387]	training's binary_logloss: 0.387379	valid_1's binary_logloss: 0.408599
# [388]	training's binary_logloss: 0.387365	valid_1's binary_logloss: 0.408585
# [389]	training's binary_logloss: 0.387344	valid_1's binary_logloss: 0.408584
# [390]	training's binary_logloss: 0.387319	valid_1's binary_logloss: 0.408576
# [391]	training's binary_logloss: 0.3873	valid_1's binary_logloss: 0.408586
# [392]	training's binary_logloss: 0.38728	valid_1's binary_logloss: 0.408565
# [393]	training's binary_logloss: 0.387255	valid_1's binary_logloss: 0.40854
# [394]	training's binary_logloss: 0.387242	valid_1's binary_logloss: 0.408529
# [395]	training's binary_logloss: 0.387228	valid_1's binary_logloss: 0.408518
# [396]	training's binary_logloss: 0.387207	valid_1's binary_logloss: 0.408495
# [397]	training's binary_logloss: 0.387189	valid_1's binary_logloss: 0.408478
# [398]	training's binary_logloss: 0.387169	valid_1's binary_logloss: 0.408476
# [399]	training's binary_logloss: 0.387132	valid_1's binary_logloss: 0.408446
# [400]	training's binary_logloss: 0.387116	valid_1's binary_logloss: 0.408428
# [401]	training's binary_logloss: 0.387101	valid_1's binary_logloss: 0.408416
# [402]	training's binary_logloss: 0.387083	valid_1's binary_logloss: 0.408392
# [403]	training's binary_logloss: 0.387067	valid_1's binary_logloss: 0.408386
# [404]	training's binary_logloss: 0.387041	valid_1's binary_logloss: 0.408363
# [405]	training's binary_logloss: 0.387007	valid_1's binary_logloss: 0.408335
# [406]	training's binary_logloss: 0.386982	valid_1's binary_logloss: 0.408313
# [407]	training's binary_logloss: 0.386965	valid_1's binary_logloss: 0.408296
# [408]	training's binary_logloss: 0.386945	valid_1's binary_logloss: 0.408299
# [409]	training's binary_logloss: 0.386926	valid_1's binary_logloss: 0.408283
# [410]	training's binary_logloss: 0.38691	valid_1's binary_logloss: 0.408259
# [411]	training's binary_logloss: 0.386881	valid_1's binary_logloss: 0.408222
# [412]	training's binary_logloss: 0.386867	valid_1's binary_logloss: 0.408209
# [413]	training's binary_logloss: 0.386853	valid_1's binary_logloss: 0.4082
# [414]	training's binary_logloss: 0.386836	valid_1's binary_logloss: 0.408184
# [415]	training's binary_logloss: 0.386806	valid_1's binary_logloss: 0.40816
# [416]	training's binary_logloss: 0.386784	valid_1's binary_logloss: 0.408134
# [417]	training's binary_logloss: 0.386764	valid_1's binary_logloss: 0.40811
# [418]	training's binary_logloss: 0.386747	valid_1's binary_logloss: 0.408097
# [419]	training's binary_logloss: 0.386729	valid_1's binary_logloss: 0.408086
# [420]	training's binary_logloss: 0.386715	valid_1's binary_logloss: 0.408086
# [421]	training's binary_logloss: 0.386701	valid_1's binary_logloss: 0.408078
# [422]	training's binary_logloss: 0.386685	valid_1's binary_logloss: 0.408074
# [423]	training's binary_logloss: 0.38667	valid_1's binary_logloss: 0.408067
# [424]	training's binary_logloss: 0.386657	valid_1's binary_logloss: 0.408055
# [425]	training's binary_logloss: 0.386636	valid_1's binary_logloss: 0.408031
# [426]	training's binary_logloss: 0.38662	valid_1's binary_logloss: 0.408021
# [427]	training's binary_logloss: 0.386603	valid_1's binary_logloss: 0.408002
# [428]	training's binary_logloss: 0.386579	valid_1's binary_logloss: 0.407991
# [429]	training's binary_logloss: 0.386564	valid_1's binary_logloss: 0.407972
# [430]	training's binary_logloss: 0.386547	valid_1's binary_logloss: 0.407959
# [431]	training's binary_logloss: 0.38652	valid_1's binary_logloss: 0.407937
# [432]	training's binary_logloss: 0.386509	valid_1's binary_logloss: 0.40793
# [433]	training's binary_logloss: 0.386491	valid_1's binary_logloss: 0.407919
# [434]	training's binary_logloss: 0.386479	valid_1's binary_logloss: 0.407903
# [435]	training's binary_logloss: 0.386464	valid_1's binary_logloss: 0.407878
# [436]	training's binary_logloss: 0.386451	valid_1's binary_logloss: 0.40786
# [437]	training's binary_logloss: 0.386437	valid_1's binary_logloss: 0.407844
# [438]	training's binary_logloss: 0.386414	valid_1's binary_logloss: 0.407832
# [439]	training's binary_logloss: 0.386395	valid_1's binary_logloss: 0.407811
# [440]	training's binary_logloss: 0.386376	valid_1's binary_logloss: 0.407792
# [441]	training's binary_logloss: 0.386358	valid_1's binary_logloss: 0.407806
# [442]	training's binary_logloss: 0.386329	valid_1's binary_logloss: 0.407775
# [443]	training's binary_logloss: 0.38631	valid_1's binary_logloss: 0.407755
# [444]	training's binary_logloss: 0.386294	valid_1's binary_logloss: 0.407757
# [445]	training's binary_logloss: 0.386274	valid_1's binary_logloss: 0.407745
# [446]	training's binary_logloss: 0.386258	valid_1's binary_logloss: 0.407724
# [447]	training's binary_logloss: 0.386242	valid_1's binary_logloss: 0.407711
# [448]	training's binary_logloss: 0.386231	valid_1's binary_logloss: 0.407704
# [449]	training's binary_logloss: 0.386208	valid_1's binary_logloss: 0.407686
# [450]	training's binary_logloss: 0.386197	valid_1's binary_logloss: 0.407678
# [451]	training's binary_logloss: 0.386184	valid_1's binary_logloss: 0.407675
# [452]	training's binary_logloss: 0.386173	valid_1's binary_logloss: 0.407667
# [453]	training's binary_logloss: 0.386161	valid_1's binary_logloss: 0.407658
# [454]	training's binary_logloss: 0.386146	valid_1's binary_logloss: 0.407643
# [455]	training's binary_logloss: 0.386134	valid_1's binary_logloss: 0.407635
# [456]	training's binary_logloss: 0.386106	valid_1's binary_logloss: 0.407614
# [457]	training's binary_logloss: 0.386095	valid_1's binary_logloss: 0.407607
# [458]	training's binary_logloss: 0.386081	valid_1's binary_logloss: 0.407591
# [459]	training's binary_logloss: 0.38606	valid_1's binary_logloss: 0.407567
# [460]	training's binary_logloss: 0.386043	valid_1's binary_logloss: 0.407545
# [461]	training's binary_logloss: 0.386027	valid_1's binary_logloss: 0.407538
# [462]	training's binary_logloss: 0.386003	valid_1's binary_logloss: 0.407526
# [463]	training's binary_logloss: 0.385991	valid_1's binary_logloss: 0.407512
# [464]	training's binary_logloss: 0.385979	valid_1's binary_logloss: 0.407494
# [465]	training's binary_logloss: 0.385961	valid_1's binary_logloss: 0.40748
# [466]	training's binary_logloss: 0.385942	valid_1's binary_logloss: 0.407468
# [467]	training's binary_logloss: 0.385926	valid_1's binary_logloss: 0.407471
# [468]	training's binary_logloss: 0.385912	valid_1's binary_logloss: 0.407453
# [469]	training's binary_logloss: 0.385899	valid_1's binary_logloss: 0.40745
# [470]	training's binary_logloss: 0.385886	valid_1's binary_logloss: 0.40744
# [471]	training's binary_logloss: 0.385872	valid_1's binary_logloss: 0.407433
# [472]	training's binary_logloss: 0.385853	valid_1's binary_logloss: 0.407412
# [473]	training's binary_logloss: 0.385841	valid_1's binary_logloss: 0.4074
# [474]	training's binary_logloss: 0.385825	valid_1's binary_logloss: 0.40739
# [475]	training's binary_logloss: 0.385807	valid_1's binary_logloss: 0.407381
# [476]	training's binary_logloss: 0.385793	valid_1's binary_logloss: 0.407368
# [477]	training's binary_logloss: 0.385768	valid_1's binary_logloss: 0.407352
# [478]	training's binary_logloss: 0.385752	valid_1's binary_logloss: 0.407332
# [479]	training's binary_logloss: 0.38574	valid_1's binary_logloss: 0.407326
# [480]	training's binary_logloss: 0.385719	valid_1's binary_logloss: 0.407317
# [481]	training's binary_logloss: 0.385702	valid_1's binary_logloss: 0.407316
# [482]	training's binary_logloss: 0.385686	valid_1's binary_logloss: 0.407305
# [483]	training's binary_logloss: 0.385663	valid_1's binary_logloss: 0.407282
# [484]	training's binary_logloss: 0.385643	valid_1's binary_logloss: 0.407268
# [485]	training's binary_logloss: 0.385624	valid_1's binary_logloss: 0.407263
# [486]	training's binary_logloss: 0.385609	valid_1's binary_logloss: 0.407241
# [487]	training's binary_logloss: 0.385599	valid_1's binary_logloss: 0.407233
# [488]	training's binary_logloss: 0.385583	valid_1's binary_logloss: 0.407229
# [489]	training's binary_logloss: 0.385573	valid_1's binary_logloss: 0.407221
# [490]	training's binary_logloss: 0.385554	valid_1's binary_logloss: 0.407209
# [491]	training's binary_logloss: 0.385542	valid_1's binary_logloss: 0.407195
# [492]	training's binary_logloss: 0.385523	valid_1's binary_logloss: 0.407187
# [493]	training's binary_logloss: 0.385505	valid_1's binary_logloss: 0.407172
# [494]	training's binary_logloss: 0.385494	valid_1's binary_logloss: 0.407161
# [495]	training's binary_logloss: 0.385482	valid_1's binary_logloss: 0.40716
# [496]	training's binary_logloss: 0.385469	valid_1's binary_logloss: 0.407143
# [497]	training's binary_logloss: 0.38545	valid_1's binary_logloss: 0.407137
# [498]	training's binary_logloss: 0.385435	valid_1's binary_logloss: 0.407125
# [499]	training's binary_logloss: 0.38542	valid_1's binary_logloss: 0.407114
# [500]	training's binary_logloss: 0.385402	valid_1's binary_logloss: 0.407104
# [501]	training's binary_logloss: 0.385389	valid_1's binary_logloss: 0.407103
# [502]	training's binary_logloss: 0.38537	valid_1's binary_logloss: 0.407086
# [503]	training's binary_logloss: 0.385352	valid_1's binary_logloss: 0.407075
# [504]	training's binary_logloss: 0.385342	valid_1's binary_logloss: 0.407067
# [505]	training's binary_logloss: 0.385331	valid_1's binary_logloss: 0.407058
# [506]	training's binary_logloss: 0.38532	valid_1's binary_logloss: 0.407042
# [507]	training's binary_logloss: 0.385308	valid_1's binary_logloss: 0.407033
# [508]	training's binary_logloss: 0.385294	valid_1's binary_logloss: 0.407023
# [509]	training's binary_logloss: 0.385274	valid_1's binary_logloss: 0.407008
# [510]	training's binary_logloss: 0.385252	valid_1's binary_logloss: 0.406987
# [511]	training's binary_logloss: 0.38524	valid_1's binary_logloss: 0.40698
# [512]	training's binary_logloss: 0.385224	valid_1's binary_logloss: 0.406971
# [513]	training's binary_logloss: 0.385213	valid_1's binary_logloss: 0.406967
# [514]	training's binary_logloss: 0.385203	valid_1's binary_logloss: 0.406961
# [515]	training's binary_logloss: 0.385187	valid_1's binary_logloss: 0.406948
# [516]	training's binary_logloss: 0.385174	valid_1's binary_logloss: 0.406935
# [517]	training's binary_logloss: 0.385158	valid_1's binary_logloss: 0.40692
# [518]	training's binary_logloss: 0.385146	valid_1's binary_logloss: 0.406917
# [519]	training's binary_logloss: 0.385131	valid_1's binary_logloss: 0.406907
# [520]	training's binary_logloss: 0.385115	valid_1's binary_logloss: 0.406891
# [521]	training's binary_logloss: 0.385102	valid_1's binary_logloss: 0.406876
# [522]	training's binary_logloss: 0.385088	valid_1's binary_logloss: 0.406864
# [523]	training's binary_logloss: 0.385074	valid_1's binary_logloss: 0.406848
# [524]	training's binary_logloss: 0.38506	valid_1's binary_logloss: 0.406835
# [525]	training's binary_logloss: 0.385048	valid_1's binary_logloss: 0.406831
# [526]	training's binary_logloss: 0.385038	valid_1's binary_logloss: 0.406828
# [527]	training's binary_logloss: 0.385021	valid_1's binary_logloss: 0.406818
# [528]	training's binary_logloss: 0.385008	valid_1's binary_logloss: 0.406806
# [529]	training's binary_logloss: 0.384999	valid_1's binary_logloss: 0.406797
# [530]	training's binary_logloss: 0.384984	valid_1's binary_logloss: 0.406787
# [531]	training's binary_logloss: 0.384973	valid_1's binary_logloss: 0.406779
# [532]	training's binary_logloss: 0.384962	valid_1's binary_logloss: 0.406772
# [533]	training's binary_logloss: 0.384946	valid_1's binary_logloss: 0.406761
# [534]	training's binary_logloss: 0.384935	valid_1's binary_logloss: 0.406743
# [535]	training's binary_logloss: 0.384924	valid_1's binary_logloss: 0.406724
# [536]	training's binary_logloss: 0.384909	valid_1's binary_logloss: 0.406713
# [537]	training's binary_logloss: 0.384896	valid_1's binary_logloss: 0.406701
# [538]	training's binary_logloss: 0.384882	valid_1's binary_logloss: 0.406689
# [539]	training's binary_logloss: 0.384869	valid_1's binary_logloss: 0.406672
# [540]	training's binary_logloss: 0.384855	valid_1's binary_logloss: 0.406657
# [541]	training's binary_logloss: 0.384841	valid_1's binary_logloss: 0.406647
# [542]	training's binary_logloss: 0.384824	valid_1's binary_logloss: 0.406636
# [543]	training's binary_logloss: 0.384813	valid_1's binary_logloss: 0.406626
# [544]	training's binary_logloss: 0.384801	valid_1's binary_logloss: 0.406617
# [545]	training's binary_logloss: 0.384791	valid_1's binary_logloss: 0.406602
# [546]	training's binary_logloss: 0.38478	valid_1's binary_logloss: 0.406604
# [547]	training's binary_logloss: 0.38477	valid_1's binary_logloss: 0.406597
# [548]	training's binary_logloss: 0.384753	valid_1's binary_logloss: 0.406576
# [549]	training's binary_logloss: 0.384742	valid_1's binary_logloss: 0.406563
# [550]	training's binary_logloss: 0.384729	valid_1's binary_logloss: 0.406552
# [551]	training's binary_logloss: 0.384722	valid_1's binary_logloss: 0.406545
# [552]	training's binary_logloss: 0.384712	valid_1's binary_logloss: 0.406538
# [553]	training's binary_logloss: 0.384701	valid_1's binary_logloss: 0.406533
# [554]	training's binary_logloss: 0.38469	valid_1's binary_logloss: 0.40652
# [555]	training's binary_logloss: 0.384681	valid_1's binary_logloss: 0.406513
# [556]	training's binary_logloss: 0.384668	valid_1's binary_logloss: 0.406503
# [557]	training's binary_logloss: 0.384656	valid_1's binary_logloss: 0.40649
# [558]	training's binary_logloss: 0.384642	valid_1's binary_logloss: 0.406482
# [559]	training's binary_logloss: 0.384631	valid_1's binary_logloss: 0.406474
# [560]	training's binary_logloss: 0.384619	valid_1's binary_logloss: 0.406464
# [561]	training's binary_logloss: 0.384601	valid_1's binary_logloss: 0.406454
# [562]	training's binary_logloss: 0.38459	valid_1's binary_logloss: 0.406445
# [563]	training's binary_logloss: 0.384579	valid_1's binary_logloss: 0.40644
# [564]	training's binary_logloss: 0.384567	valid_1's binary_logloss: 0.406424
# [565]	training's binary_logloss: 0.384556	valid_1's binary_logloss: 0.406418
# [566]	training's binary_logloss: 0.384543	valid_1's binary_logloss: 0.406414
# [567]	training's binary_logloss: 0.384533	valid_1's binary_logloss: 0.406399
# [568]	training's binary_logloss: 0.384524	valid_1's binary_logloss: 0.406387
# [569]	training's binary_logloss: 0.384517	valid_1's binary_logloss: 0.406351
# [570]	training's binary_logloss: 0.384504	valid_1's binary_logloss: 0.406341
# [571]	training's binary_logloss: 0.384489	valid_1's binary_logloss: 0.406326
# [572]	training's binary_logloss: 0.384474	valid_1's binary_logloss: 0.406295
# [573]	training's binary_logloss: 0.384462	valid_1's binary_logloss: 0.406285
# [574]	training's binary_logloss: 0.384453	valid_1's binary_logloss: 0.406274
# [575]	training's binary_logloss: 0.384437	valid_1's binary_logloss: 0.406266
# [576]	training's binary_logloss: 0.384422	valid_1's binary_logloss: 0.406253
# [577]	training's binary_logloss: 0.384411	valid_1's binary_logloss: 0.406243
# [578]	training's binary_logloss: 0.3844	valid_1's binary_logloss: 0.40624
# [579]	training's binary_logloss: 0.38439	valid_1's binary_logloss: 0.406227
# [580]	training's binary_logloss: 0.384378	valid_1's binary_logloss: 0.406221
# [581]	training's binary_logloss: 0.384365	valid_1's binary_logloss: 0.406214
# [582]	training's binary_logloss: 0.384347	valid_1's binary_logloss: 0.406201
# [583]	training's binary_logloss: 0.384333	valid_1's binary_logloss: 0.406182
# [584]	training's binary_logloss: 0.384325	valid_1's binary_logloss: 0.406177
# [585]	training's binary_logloss: 0.384313	valid_1's binary_logloss: 0.406171
# [586]	training's binary_logloss: 0.384297	valid_1's binary_logloss: 0.406159
# [587]	training's binary_logloss: 0.384285	valid_1's binary_logloss: 0.406152
# [588]	training's binary_logloss: 0.384273	valid_1's binary_logloss: 0.406142
# [589]	training's binary_logloss: 0.384265	valid_1's binary_logloss: 0.406132
# [590]	training's binary_logloss: 0.384249	valid_1's binary_logloss: 0.406129
# [591]	training's binary_logloss: 0.38424	valid_1's binary_logloss: 0.406121
# [592]	training's binary_logloss: 0.384222	valid_1's binary_logloss: 0.406103
# [593]	training's binary_logloss: 0.384213	valid_1's binary_logloss: 0.406097
# [594]	training's binary_logloss: 0.384204	valid_1's binary_logloss: 0.406098
# [595]	training's binary_logloss: 0.384187	valid_1's binary_logloss: 0.406089
# [596]	training's binary_logloss: 0.384171	valid_1's binary_logloss: 0.406063
# [597]	training's binary_logloss: 0.384164	valid_1's binary_logloss: 0.406051
# [598]	training's binary_logloss: 0.384151	valid_1's binary_logloss: 0.406041
# [599]	training's binary_logloss: 0.384145	valid_1's binary_logloss: 0.406036
# [600]	training's binary_logloss: 0.384128	valid_1's binary_logloss: 0.406023
# [601]	training's binary_logloss: 0.384117	valid_1's binary_logloss: 0.406018
# [602]	training's binary_logloss: 0.384107	valid_1's binary_logloss: 0.40601
# [603]	training's binary_logloss: 0.384098	valid_1's binary_logloss: 0.406007
# [604]	training's binary_logloss: 0.384085	valid_1's binary_logloss: 0.406019
# [605]	training's binary_logloss: 0.384076	valid_1's binary_logloss: 0.40601
# [606]	training's binary_logloss: 0.384065	valid_1's binary_logloss: 0.406017
# [607]	training's binary_logloss: 0.384052	valid_1's binary_logloss: 0.405998
# [608]	training's binary_logloss: 0.384043	valid_1's binary_logloss: 0.405999
# [609]	training's binary_logloss: 0.384037	valid_1's binary_logloss: 0.405995
# [610]	training's binary_logloss: 0.384014	valid_1's binary_logloss: 0.40598
# [611]	training's binary_logloss: 0.383992	valid_1's binary_logloss: 0.405959
# [612]	training's binary_logloss: 0.383974	valid_1's binary_logloss: 0.405941
# [613]	training's binary_logloss: 0.383963	valid_1's binary_logloss: 0.405933
# [614]	training's binary_logloss: 0.383953	valid_1's binary_logloss: 0.405942
# [615]	training's binary_logloss: 0.383943	valid_1's binary_logloss: 0.40593
# [616]	training's binary_logloss: 0.383928	valid_1's binary_logloss: 0.405918
# [617]	training's binary_logloss: 0.383919	valid_1's binary_logloss: 0.405917
# [618]	training's binary_logloss: 0.383907	valid_1's binary_logloss: 0.405909
# [619]	training's binary_logloss: 0.383895	valid_1's binary_logloss: 0.405893
# [620]	training's binary_logloss: 0.383883	valid_1's binary_logloss: 0.405883
# [621]	training's binary_logloss: 0.383875	valid_1's binary_logloss: 0.405877
# [622]	training's binary_logloss: 0.383865	valid_1's binary_logloss: 0.405866
# [623]	training's binary_logloss: 0.383858	valid_1's binary_logloss: 0.405862
# [624]	training's binary_logloss: 0.383848	valid_1's binary_logloss: 0.405854
# [625]	training's binary_logloss: 0.383838	valid_1's binary_logloss: 0.40585
# ...
# [1804]	training's binary_logloss: 0.377287	valid_1's binary_logloss: 0.40054
# [1805]	training's binary_logloss: 0.377284	valid_1's binary_logloss: 0.400537
# [1806]	training's binary_logloss: 0.37728	valid_1's binary_logloss: 0.400534
# [1807]	training's binary_logloss: 0.377277	valid_1's binary_logloss: 0.400531
# [1808]	training's binary_logloss: 0.377274	valid_1's binary_logloss: 0.40053
# [1809]	training's binary_logloss: 0.377269	valid_1's binary_logloss: 0.400522
# [1810]	training's binary_logloss: 0.377266	valid_1's binary_logloss: 0.400524
# [1811]	training's binary_logloss: 0.377259	valid_1's binary_logloss: 0.400519
# [1812]	training's binary_logloss: 0.377257	valid_1's binary_logloss: 0.400518
# [1813]	training's binary_logloss: 0.377253	valid_1's binary_logloss: 0.400515
# [1814]	training's binary_logloss: 0.377249	valid_1's binary_logloss: 0.400513
# [1815]	training's binary_logloss: 0.377247	valid_1's binary_logloss: 0.400512
# [1816]	training's binary_logloss: 0.377246	valid_1's binary_logloss: 0.400512
# [1817]	training's binary_logloss: 0.377243	valid_1's binary_logloss: 0.40051
# [1818]	training's binary_logloss: 0.37724	valid_1's binary_logloss: 0.400505
# [1819]	training's binary_logloss: 0.377236	valid_1's binary_logloss: 0.400503
# [1820]	training's binary_logloss: 0.377234	valid_1's binary_logloss: 0.400501
# [1821]	training's binary_logloss: 0.377232	valid_1's binary_logloss: 0.400497
# [1822]	training's binary_logloss: 0.377231	valid_1's binary_logloss: 0.400496
# [1823]	training's binary_logloss: 0.377229	valid_1's binary_logloss: 0.400497
# [1824]	training's binary_logloss: 0.377225	valid_1's binary_logloss: 0.400494
# [1825]	training's binary_logloss: 0.377223	valid_1's binary_logloss: 0.400493
# [1826]	training's binary_logloss: 0.377221	valid_1's binary_logloss: 0.400493
# [1827]	training's binary_logloss: 0.377217	valid_1's binary_logloss: 0.400489
# [1828]	training's binary_logloss: 0.377215	valid_1's binary_logloss: 0.400488
# [1829]	training's binary_logloss: 0.377212	valid_1's binary_logloss: 0.400486
# [1830]	training's binary_logloss: 0.377209	valid_1's binary_logloss: 0.400485
# [1831]	training's binary_logloss: 0.377204	valid_1's binary_logloss: 0.400479
# [1832]	training's binary_logloss: 0.3772	valid_1's binary_logloss: 0.400476
# [1833]	training's binary_logloss: 0.377198	valid_1's binary_logloss: 0.400476
# [1834]	training's binary_logloss: 0.377196	valid_1's binary_logloss: 0.400475
# [1835]	training's binary_logloss: 0.377193	valid_1's binary_logloss: 0.400473
# [1836]	training's binary_logloss: 0.37719	valid_1's binary_logloss: 0.400469
# [1837]	training's binary_logloss: 0.377184	valid_1's binary_logloss: 0.400464
# [1838]	training's binary_logloss: 0.37718	valid_1's binary_logloss: 0.400459
# [1839]	training's binary_logloss: 0.377172	valid_1's binary_logloss: 0.40045
# [1840]	training's binary_logloss: 0.37717	valid_1's binary_logloss: 0.40045
# [1841]	training's binary_logloss: 0.377165	valid_1's binary_logloss: 0.400445
# [1842]	training's binary_logloss: 0.377163	valid_1's binary_logloss: 0.400444
# [1843]	training's binary_logloss: 0.377158	valid_1's binary_logloss: 0.400442
# [1844]	training's binary_logloss: 0.377155	valid_1's binary_logloss: 0.40044
# [1845]	training's binary_logloss: 0.37715	valid_1's binary_logloss: 0.400432
# [1846]	training's binary_logloss: 0.377148	valid_1's binary_logloss: 0.400431
# [1847]	training's binary_logloss: 0.377146	valid_1's binary_logloss: 0.400429
# [1848]	training's binary_logloss: 0.377145	valid_1's binary_logloss: 0.400429
# [1849]	training's binary_logloss: 0.377143	valid_1's binary_logloss: 0.400428
# [1850]	training's binary_logloss: 0.377141	valid_1's binary_logloss: 0.400427
# [1851]	training's binary_logloss: 0.377135	valid_1's binary_logloss: 0.400421
# [1852]	training's binary_logloss: 0.377131	valid_1's binary_logloss: 0.400418
# [1853]	training's binary_logloss: 0.377129	valid_1's binary_logloss: 0.400421
# [1854]	training's binary_logloss: 0.377125	valid_1's binary_logloss: 0.400418
# [1855]	training's binary_logloss: 0.377122	valid_1's binary_logloss: 0.400414
# [1856]	training's binary_logloss: 0.377119	valid_1's binary_logloss: 0.400411
# [1857]	training's binary_logloss: 0.377116	valid_1's binary_logloss: 0.400407
# [1858]	training's binary_logloss: 0.377114	valid_1's binary_logloss: 0.400407
# [1859]	training's binary_logloss: 0.377109	valid_1's binary_logloss: 0.400399
# [1860]	training's binary_logloss: 0.377107	valid_1's binary_logloss: 0.400398
# [1861]	training's binary_logloss: 0.377105	valid_1's binary_logloss: 0.400396
# [1862]	training's binary_logloss: 0.377096	valid_1's binary_logloss: 0.40039
# [1863]	training's binary_logloss: 0.377091	valid_1's binary_logloss: 0.400385
# [1864]	training's binary_logloss: 0.377089	valid_1's binary_logloss: 0.400383
# [1865]	training's binary_logloss: 0.377086	valid_1's binary_logloss: 0.400384
# [1866]	training's binary_logloss: 0.377084	valid_1's binary_logloss: 0.40038
# [1867]	training's binary_logloss: 0.37708	valid_1's binary_logloss: 0.400376
# [1868]	training's binary_logloss: 0.377077	valid_1's binary_logloss: 0.400372
# [1869]	training's binary_logloss: 0.377074	valid_1's binary_logloss: 0.40037
# [1870]	training's binary_logloss: 0.37707	valid_1's binary_logloss: 0.400369
# [1871]	training's binary_logloss: 0.377069	valid_1's binary_logloss: 0.400368
# [1872]	training's binary_logloss: 0.377067	valid_1's binary_logloss: 0.400367
# [1873]	training's binary_logloss: 0.377062	valid_1's binary_logloss: 0.400363
# [1874]	training's binary_logloss: 0.377059	valid_1's binary_logloss: 0.400361
# [1875]	training's binary_logloss: 0.377057	valid_1's binary_logloss: 0.400359
# [1876]	training's binary_logloss: 0.377054	valid_1's binary_logloss: 0.400357
# [1877]	training's binary_logloss: 0.37705	valid_1's binary_logloss: 0.400356
# [1878]	training's binary_logloss: 0.377047	valid_1's binary_logloss: 0.400355
# [1879]	training's binary_logloss: 0.377045	valid_1's binary_logloss: 0.400354
# [1880]	training's binary_logloss: 0.377044	valid_1's binary_logloss: 0.400348
# [1881]	training's binary_logloss: 0.377041	valid_1's binary_logloss: 0.400345
# [1882]	training's binary_logloss: 0.377038	valid_1's binary_logloss: 0.400344
# [1883]	training's binary_logloss: 0.377035	valid_1's binary_logloss: 0.400339
# [1884]	training's binary_logloss: 0.377033	valid_1's binary_logloss: 0.400336
# [1885]	training's binary_logloss: 0.377032	valid_1's binary_logloss: 0.400335
# [1886]	training's binary_logloss: 0.37703	valid_1's binary_logloss: 0.400335
# [1887]	training's binary_logloss: 0.377028	valid_1's binary_logloss: 0.400339
# [1888]	training's binary_logloss: 0.377024	valid_1's binary_logloss: 0.400335
# [1889]	training's binary_logloss: 0.377021	valid_1's binary_logloss: 0.400334
# [1890]	training's binary_logloss: 0.377019	valid_1's binary_logloss: 0.400333
# [1891]	training's binary_logloss: 0.377016	valid_1's binary_logloss: 0.400327
# [1892]	training's binary_logloss: 0.377014	valid_1's binary_logloss: 0.400319
# [1893]	training's binary_logloss: 0.377011	valid_1's binary_logloss: 0.400318
# [1894]	training's binary_logloss: 0.377008	valid_1's binary_logloss: 0.400316
# [1895]	training's binary_logloss: 0.377007	valid_1's binary_logloss: 0.400314
# [1896]	training's binary_logloss: 0.377004	valid_1's binary_logloss: 0.400313
# [1897]	training's binary_logloss: 0.377003	valid_1's binary_logloss: 0.400313
# [1898]	training's binary_logloss: 0.377001	valid_1's binary_logloss: 0.400312
# [1899]	training's binary_logloss: 0.377	valid_1's binary_logloss: 0.400312
# [1900]	training's binary_logloss: 0.376998	valid_1's binary_logloss: 0.400309
# [1901]	training's binary_logloss: 0.376994	valid_1's binary_logloss: 0.400311
# [1902]	training's binary_logloss: 0.376992	valid_1's binary_logloss: 0.40031
# [1903]	training's binary_logloss: 0.37699	valid_1's binary_logloss: 0.400309
# [1904]	training's binary_logloss: 0.376985	valid_1's binary_logloss: 0.400305
# [1905]	training's binary_logloss: 0.376981	valid_1's binary_logloss: 0.400301
# [1906]	training's binary_logloss: 0.376978	valid_1's binary_logloss: 0.400299
# [1907]	training's binary_logloss: 0.376976	valid_1's binary_logloss: 0.400297
# [1908]	training's binary_logloss: 0.376974	valid_1's binary_logloss: 0.400296
# [1909]	training's binary_logloss: 0.376973	valid_1's binary_logloss: 0.400293
# [1910]	training's binary_logloss: 0.376969	valid_1's binary_logloss: 0.400293
# [1911]	training's binary_logloss: 0.376966	valid_1's binary_logloss: 0.40029
# [1912]	training's binary_logloss: 0.376963	valid_1's binary_logloss: 0.400286
# [1913]	training's binary_logloss: 0.376962	valid_1's binary_logloss: 0.400285
# [1914]	training's binary_logloss: 0.37696	valid_1's binary_logloss: 0.400284
# [1915]	training's binary_logloss: 0.376958	valid_1's binary_logloss: 0.400282
# [1916]	training's binary_logloss: 0.376956	valid_1's binary_logloss: 0.400282
# [1917]	training's binary_logloss: 0.376955	valid_1's binary_logloss: 0.400279
# [1918]	training's binary_logloss: 0.376953	valid_1's binary_logloss: 0.400279
# [1919]	training's binary_logloss: 0.376949	valid_1's binary_logloss: 0.400273
# [1920]	training's binary_logloss: 0.376944	valid_1's binary_logloss: 0.400268
# [1921]	training's binary_logloss: 0.376942	valid_1's binary_logloss: 0.400263
# [1922]	training's binary_logloss: 0.37694	valid_1's binary_logloss: 0.400256
# [1923]	training's binary_logloss: 0.376939	valid_1's binary_logloss: 0.400255
# [1924]	training's binary_logloss: 0.376936	valid_1's binary_logloss: 0.400254
# [1925]	training's binary_logloss: 0.376933	valid_1's binary_logloss: 0.400252
# [1926]	training's binary_logloss: 0.376932	valid_1's binary_logloss: 0.400251
# [1927]	training's binary_logloss: 0.376931	valid_1's binary_logloss: 0.400251
# [1928]	training's binary_logloss: 0.37693	valid_1's binary_logloss: 0.400251
# [1929]	training's binary_logloss: 0.376928	valid_1's binary_logloss: 0.400246
# [1930]	training's binary_logloss: 0.376927	valid_1's binary_logloss: 0.400246
# [1931]	training's binary_logloss: 0.376925	valid_1's binary_logloss: 0.400244
# [1932]	training's binary_logloss: 0.376923	valid_1's binary_logloss: 0.400243
# [1933]	training's binary_logloss: 0.37692	valid_1's binary_logloss: 0.40024
# [1934]	training's binary_logloss: 0.376917	valid_1's binary_logloss: 0.400238
# [1935]	training's binary_logloss: 0.376912	valid_1's binary_logloss: 0.400234
# [1936]	training's binary_logloss: 0.376909	valid_1's binary_logloss: 0.400237
# [1937]	training's binary_logloss: 0.376905	valid_1's binary_logloss: 0.400233
# [1938]	training's binary_logloss: 0.376902	valid_1's binary_logloss: 0.400231
# [1939]	training's binary_logloss: 0.376897	valid_1's binary_logloss: 0.400228
# [1940]	training's binary_logloss: 0.376893	valid_1's binary_logloss: 0.400224
# [1941]	training's binary_logloss: 0.376891	valid_1's binary_logloss: 0.400222
# [1942]	training's binary_logloss: 0.376886	valid_1's binary_logloss: 0.400216
# [1943]	training's binary_logloss: 0.376883	valid_1's binary_logloss: 0.400222
# [1944]	training's binary_logloss: 0.37688	valid_1's binary_logloss: 0.400221
# [1945]	training's binary_logloss: 0.376878	valid_1's binary_logloss: 0.400221
# [1946]	training's binary_logloss: 0.376873	valid_1's binary_logloss: 0.400217
# [1947]	training's binary_logloss: 0.376871	valid_1's binary_logloss: 0.400217
# [1948]	training's binary_logloss: 0.376869	valid_1's binary_logloss: 0.400216
# [1949]	training's binary_logloss: 0.376865	valid_1's binary_logloss: 0.400214
# [1950]	training's binary_logloss: 0.376862	valid_1's binary_logloss: 0.40021
# [1951]	training's binary_logloss: 0.37686	valid_1's binary_logloss: 0.400207
# [1952]	training's binary_logloss: 0.376858	valid_1's binary_logloss: 0.400205
# [1953]	training's binary_logloss: 0.376856	valid_1's binary_logloss: 0.400206
# [1954]	training's binary_logloss: 0.376854	valid_1's binary_logloss: 0.400205
# [1955]	training's binary_logloss: 0.376851	valid_1's binary_logloss: 0.400202
# [1956]	training's binary_logloss: 0.376848	valid_1's binary_logloss: 0.400199
# [1957]	training's binary_logloss: 0.376845	valid_1's binary_logloss: 0.400189
# [1958]	training's binary_logloss: 0.376844	valid_1's binary_logloss: 0.400188
# [1959]	training's binary_logloss: 0.376841	valid_1's binary_logloss: 0.400187
# [1960]	training's binary_logloss: 0.376838	valid_1's binary_logloss: 0.400185
# [1961]	training's binary_logloss: 0.376836	valid_1's binary_logloss: 0.400183
# [1962]	training's binary_logloss: 0.376833	valid_1's binary_logloss: 0.400184
# [1963]	training's binary_logloss: 0.37683	valid_1's binary_logloss: 0.400182
# [1964]	training's binary_logloss: 0.376826	valid_1's binary_logloss: 0.40018
# [1965]	training's binary_logloss: 0.376821	valid_1's binary_logloss: 0.400178
# [1966]	training's binary_logloss: 0.376819	valid_1's binary_logloss: 0.400181
# [1967]	training's binary_logloss: 0.376817	valid_1's binary_logloss: 0.40018
# [1968]	training's binary_logloss: 0.376814	valid_1's binary_logloss: 0.400176
# [1969]	training's binary_logloss: 0.376812	valid_1's binary_logloss: 0.400176
# [1970]	training's binary_logloss: 0.376811	valid_1's binary_logloss: 0.400176
# [1971]	training's binary_logloss: 0.376808	valid_1's binary_logloss: 0.400175
# [1972]	training's binary_logloss: 0.376806	valid_1's binary_logloss: 0.400174
# [1973]	training's binary_logloss: 0.376802	valid_1's binary_logloss: 0.400168
# [1974]	training's binary_logloss: 0.376798	valid_1's binary_logloss: 0.40016
# [1975]	training's binary_logloss: 0.376795	valid_1's binary_logloss: 0.400159
# [1976]	training's binary_logloss: 0.376793	valid_1's binary_logloss: 0.400157
# [1977]	training's binary_logloss: 0.37679	valid_1's binary_logloss: 0.400157
# [1978]	training's binary_logloss: 0.376786	valid_1's binary_logloss: 0.400155
# [1979]	training's binary_logloss: 0.376784	valid_1's binary_logloss: 0.400153
# [1980]	training's binary_logloss: 0.376783	valid_1's binary_logloss: 0.400153
# [1981]	training's binary_logloss: 0.376779	valid_1's binary_logloss: 0.400147
# [1982]	training's binary_logloss: 0.376776	valid_1's binary_logloss: 0.400146
# [1983]	training's binary_logloss: 0.376775	valid_1's binary_logloss: 0.40014
# [1984]	training's binary_logloss: 0.376773	valid_1's binary_logloss: 0.400139
# [1985]	training's binary_logloss: 0.376768	valid_1's binary_logloss: 0.400137
# [1986]	training's binary_logloss: 0.376766	valid_1's binary_logloss: 0.400139
# [1987]	training's binary_logloss: 0.376764	valid_1's binary_logloss: 0.400134
# [1988]	training's binary_logloss: 0.376762	valid_1's binary_logloss: 0.400137
# [1989]	training's binary_logloss: 0.376761	valid_1's binary_logloss: 0.400136
# [1990]	training's binary_logloss: 0.376756	valid_1's binary_logloss: 0.400134
# [1991]	training's binary_logloss: 0.376753	valid_1's binary_logloss: 0.400132
# [1992]	training's binary_logloss: 0.376752	valid_1's binary_logloss: 0.400131
# [1993]	training's binary_logloss: 0.37675	valid_1's binary_logloss: 0.40013
# [1994]	training's binary_logloss: 0.376747	valid_1's binary_logloss: 0.400126
# [1995]	training's binary_logloss: 0.376744	valid_1's binary_logloss: 0.400123
# [1996]	training's binary_logloss: 0.376741	valid_1's binary_logloss: 0.400121
# [1997]	training's binary_logloss: 0.376738	valid_1's binary_logloss: 0.400112
# [1998]	training's binary_logloss: 0.376736	valid_1's binary_logloss: 0.400118
# [1999]	training's binary_logloss: 0.376732	valid_1's binary_logloss: 0.400115
# [2000]	training's binary_logloss: 0.376729	valid_1's binary_logloss: 0.400114
# Did not meet early stopping. Best iteration is:
# [2000]	training's binary_logloss: 0.376729	valid_1's binary_logloss: 0.400114
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.3,
#                importance_type='split', learning_rate=0.02, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=2000, n_jobs=-1, num_leaves=16, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, seed=99,
#                silent=True, subsample=0.7, subsample_for_bin=200000,
#                subsample_freq=2)

# %%
#生成提交用的submission
submission=pd.read_csv('sampleSubmission.csv')
test_predict = lgb_model.predict_proba(x_test)[:, 1]

# %%
submission['click']=test_predict
submission.to_csv("submission1.csv", index=False)

# %%
submission.head()
# Out:
#                      id     click
# 0  10000174058809263569  0.068204
# 1  10000182526920855428  0.219892
# 2  10000554139829213984  0.210251
# 3  10001094637809798845  0.042106
# 4  10001377041558670745  0.220065
