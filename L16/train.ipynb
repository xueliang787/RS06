# %%
# 训练五子棋AI

from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch

class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 10
        self.board_height = 10
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
    # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# C:\Users\xueliang.chen\RS\L16\AlphaZero\policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# D:\install_path\Anaconda\envs\pytorch-gpu\lib\site-packages\torch\nn\functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:21
# batch i:2, episode_len:24
# batch i:3, episode_len:9
# batch i:4, episode_len:19
# kl:0.02821,lr_multiplier:1.000,loss:5.554256916046143,entropy:4.5805745124816895,explained_var_old:-0.001,explained_var_new:0.073
# batch i:5, episode_len:22
# kl:0.00815,lr_multiplier:1.500,loss:5.549987316131592,entropy:4.565126419067383,explained_var_old:0.000,explained_var_new:0.027
# batch i:6, episode_len:20
# kl:0.01013,lr_multiplier:1.500,loss:5.270323753356934,entropy:4.569490432739258,explained_var_old:0.019,explained_var_new:0.450
# batch i:7, episode_len:18
# kl:0.06804,lr_multiplier:1.000,loss:5.024531364440918,entropy:4.556539535522461,explained_var_old:0.299,explained_var_new:0.584
# batch i:8, episode_len:17
# kl:0.08592,lr_multiplier:0.667,loss:5.192836284637451,entropy:4.540412425994873,explained_var_old:0.363,explained_var_new:0.375
# batch i:9, episode_len:19
# kl:0.04252,lr_multiplier:0.444,loss:5.079582691192627,entropy:4.4363837242126465,explained_var_old:0.398,explained_var_new:0.450
# batch i:10, episode_len:12
# kl:0.00407,lr_multiplier:0.667,loss:5.122786521911621,entropy:4.510077476501465,explained_var_old:0.319,explained_var_new:0.380
# batch i:11, episode_len:10
# kl:0.00866,lr_multiplier:1.000,loss:5.047054767608643,entropy:4.465639591217041,explained_var_old:0.303,explained_var_new:0.410
# batch i:12, episode_len:20
# kl:0.01404,lr_multiplier:1.000,loss:4.859565734863281,entropy:4.409741401672363,explained_var_old:0.531,explained_var_new:0.579
# batch i:13, episode_len:26
# kl:0.01283,lr_multiplier:1.000,loss:4.747337818145752,entropy:4.362058639526367,explained_var_old:0.597,explained_var_new:0.647
# batch i:14, episode_len:19
# kl:0.00792,lr_multiplier:1.500,loss:4.767470359802246,entropy:4.35804557800293,explained_var_old:0.534,explained_var_new:0.602
# batch i:15, episode_len:10
# kl:0.04771,lr_multiplier:1.000,loss:4.70444917678833,entropy:4.311491012573242,explained_var_old:0.582,explained_var_new:0.605
# batch i:16, episode_len:22
# kl:0.03868,lr_multiplier:1.000,loss:4.6230363845825195,entropy:4.319164752960205,explained_var_old:0.621,explained_var_new:0.686
# batch i:17, episode_len:7
# kl:0.03737,lr_multiplier:1.000,loss:4.5306715965271,entropy:4.248135089874268,explained_var_old:0.658,explained_var_new:0.698
# batch i:18, episode_len:22
# kl:0.02652,lr_multiplier:1.000,loss:4.787167549133301,entropy:4.22440242767334,explained_var_old:0.422,explained_var_new:0.465
# batch i:19, episode_len:23
# kl:0.05167,lr_multiplier:0.667,loss:4.671928405761719,entropy:4.144155502319336,explained_var_old:0.488,explained_var_new:0.521
# batch i:20, episode_len:16
# kl:0.05031,lr_multiplier:0.444,loss:4.743827819824219,entropy:4.189014911651611,explained_var_old:0.370,explained_var_new:0.403
# batch i:21, episode_len:35
# kl:0.02863,lr_multiplier:0.444,loss:4.7295989990234375,entropy:4.143926620483398,explained_var_old:0.311,explained_var_new:0.380
# batch i:22, episode_len:18
# kl:0.01598,lr_multiplier:0.444,loss:4.794321537017822,entropy:4.0679612159729,explained_var_old:0.289,explained_var_new:0.326
# batch i:23, episode_len:24
# kl:0.03852,lr_multiplier:0.444,loss:4.652332305908203,entropy:4.114411354064941,explained_var_old:0.392,explained_var_new:0.413
# batch i:24, episode_len:25
# kl:0.02866,lr_multiplier:0.444,loss:4.706115245819092,entropy:4.1023688316345215,explained_var_old:0.354,explained_var_new:0.405
# batch i:25, episode_len:12
# kl:0.01228,lr_multiplier:0.444,loss:4.698420524597168,entropy:4.061991214752197,explained_var_old:0.363,explained_var_new:0.384
# batch i:26, episode_len:21
# kl:0.02913,lr_multiplier:0.444,loss:4.651192665100098,entropy:3.9276483058929443,explained_var_old:0.276,explained_var_new:0.329
# batch i:27, episode_len:17
# kl:0.05553,lr_multiplier:0.296,loss:4.7722625732421875,entropy:4.126917362213135,explained_var_old:0.292,explained_var_new:0.298
# batch i:28, episode_len:15
# kl:0.01055,lr_multiplier:0.296,loss:4.706283092498779,entropy:4.079854488372803,explained_var_old:0.253,explained_var_new:0.273
# batch i:29, episode_len:14
# kl:0.02822,lr_multiplier:0.296,loss:4.671693325042725,entropy:3.9192452430725098,explained_var_old:0.314,explained_var_new:0.328
# batch i:30, episode_len:10
# kl:0.02440,lr_multiplier:0.296,loss:4.596437931060791,entropy:3.967379570007324,explained_var_old:0.309,explained_var_new:0.348
# batch i:31, episode_len:11
# kl:0.01884,lr_multiplier:0.296,loss:4.729568004608154,entropy:4.052004814147949,explained_var_old:0.335,explained_var_new:0.345
# batch i:32, episode_len:15
# kl:0.00881,lr_multiplier:0.444,loss:4.673243045806885,entropy:4.038652420043945,explained_var_old:0.229,explained_var_new:0.285
# batch i:33, episode_len:18
# kl:0.03018,lr_multiplier:0.444,loss:4.648733615875244,entropy:3.9330906867980957,explained_var_old:0.251,explained_var_new:0.276
# batch i:34, episode_len:9
# kl:0.01956,lr_multiplier:0.444,loss:4.604057788848877,entropy:3.964586019515991,explained_var_old:0.307,explained_var_new:0.319
# batch i:35, episode_len:23
# kl:0.01311,lr_multiplier:0.444,loss:4.561944007873535,entropy:3.903398275375366,explained_var_old:0.322,explained_var_new:0.341
# batch i:36, episode_len:13
# kl:0.01176,lr_multiplier:0.444,loss:4.670516490936279,entropy:3.913876533508301,explained_var_old:0.219,explained_var_new:0.237
# batch i:37, episode_len:12
# kl:0.00945,lr_multiplier:0.667,loss:4.619645118713379,entropy:3.9326822757720947,explained_var_old:0.259,explained_var_new:0.282
# batch i:38, episode_len:16
# kl:0.01886,lr_multiplier:0.667,loss:4.587341785430908,entropy:3.9570744037628174,explained_var_old:0.322,explained_var_new:0.348
# batch i:39, episode_len:14
# kl:0.02131,lr_multiplier:0.667,loss:4.54032564163208,entropy:3.8702986240386963,explained_var_old:0.293,explained_var_new:0.345
# batch i:40, episode_len:15
# kl:0.02299,lr_multiplier:0.667,loss:4.4086594581604,entropy:3.816807746887207,explained_var_old:0.339,explained_var_new:0.393
# batch i:41, episode_len:15
# kl:0.04074,lr_multiplier:0.444,loss:4.392982006072998,entropy:3.897427558898926,explained_var_old:0.394,explained_var_new:0.424
# batch i:42, episode_len:13
# kl:0.03038,lr_multiplier:0.444,loss:4.448802471160889,entropy:3.937999963760376,explained_var_old:0.385,explained_var_new:0.424
# batch i:43, episode_len:22
# kl:0.02279,lr_multiplier:0.444,loss:4.4535627365112305,entropy:3.7584879398345947,explained_var_old:0.294,explained_var_new:0.330
# batch i:44, episode_len:12
# kl:0.01790,lr_multiplier:0.444,loss:4.424797058105469,entropy:3.8363428115844727,explained_var_old:0.382,explained_var_new:0.409
# batch i:45, episode_len:13
# kl:0.01110,lr_multiplier:0.444,loss:4.4107561111450195,entropy:3.8264927864074707,explained_var_old:0.390,explained_var_new:0.408
# batch i:46, episode_len:10
# kl:0.01675,lr_multiplier:0.444,loss:4.365338325500488,entropy:3.7677297592163086,explained_var_old:0.370,explained_var_new:0.414
# batch i:47, episode_len:22
# kl:0.02505,lr_multiplier:0.444,loss:4.395521640777588,entropy:3.8795204162597656,explained_var_old:0.376,explained_var_new:0.409
# batch i:48, episode_len:26
# kl:0.00990,lr_multiplier:0.667,loss:4.467029571533203,entropy:3.8454501628875732,explained_var_old:0.269,explained_var_new:0.302
# batch i:49, episode_len:10
# kl:0.02107,lr_multiplier:0.667,loss:4.433553695678711,entropy:3.7892637252807617,explained_var_old:0.315,explained_var_new:0.367
# batch i:50, episode_len:12
# kl:0.02407,lr_multiplier:0.667,loss:4.444725036621094,entropy:3.7435555458068848,explained_var_old:0.232,explained_var_new:0.284
# current self-play batch: 50
# num_playouts:1000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:15
# kl:0.03387,lr_multiplier:0.667,loss:4.361109256744385,entropy:3.823225259780884,explained_var_old:0.370,explained_var_new:0.413
# batch i:52, episode_len:9
# kl:0.03892,lr_multiplier:0.667,loss:4.338539123535156,entropy:3.653311252593994,explained_var_old:0.314,explained_var_new:0.363
# batch i:53, episode_len:8
# kl:0.03845,lr_multiplier:0.667,loss:4.347799301147461,entropy:3.7263717651367188,explained_var_old:0.292,explained_var_new:0.360
# batch i:54, episode_len:11
# kl:0.02391,lr_multiplier:0.667,loss:4.343895435333252,entropy:3.8167247772216797,explained_var_old:0.326,explained_var_new:0.379
# batch i:55, episode_len:10
# kl:0.02056,lr_multiplier:0.667,loss:4.345908164978027,entropy:3.690516471862793,explained_var_old:0.334,explained_var_new:0.375
# batch i:56, episode_len:22
# kl:0.02530,lr_multiplier:0.667,loss:4.391136646270752,entropy:3.7693769931793213,explained_var_old:0.243,explained_var_new:0.315
# batch i:57, episode_len:19
# kl:0.03760,lr_multiplier:0.667,loss:4.261557579040527,entropy:3.650599956512451,explained_var_old:0.329,explained_var_new:0.385
# batch i:58, episode_len:9
# kl:0.01897,lr_multiplier:0.667,loss:4.326398849487305,entropy:3.7124922275543213,explained_var_old:0.286,explained_var_new:0.376
# batch i:59, episode_len:7
# kl:0.05482,lr_multiplier:0.444,loss:4.327868938446045,entropy:3.557770252227783,explained_var_old:0.277,explained_var_new:0.346
# batch i:60, episode_len:20
# kl:0.02638,lr_multiplier:0.444,loss:4.232477188110352,entropy:3.5988035202026367,explained_var_old:0.315,explained_var_new:0.375
# batch i:61, episode_len:12
# kl:0.01661,lr_multiplier:0.444,loss:4.307620048522949,entropy:3.7471699714660645,explained_var_old:0.370,explained_var_new:0.411
# batch i:62, episode_len:16
# kl:0.02203,lr_multiplier:0.444,loss:4.215071678161621,entropy:3.648019790649414,explained_var_old:0.394,explained_var_new:0.431
# batch i:63, episode_len:17
# kl:0.01522,lr_multiplier:0.444,loss:4.181325435638428,entropy:3.682669162750244,explained_var_old:0.405,explained_var_new:0.444
# batch i:64, episode_len:21
# kl:0.01777,lr_multiplier:0.444,loss:4.274856090545654,entropy:3.650088310241699,explained_var_old:0.304,explained_var_new:0.351
# batch i:65, episode_len:17
# kl:0.01655,lr_multiplier:0.444,loss:4.246265888214111,entropy:3.6285176277160645,explained_var_old:0.321,explained_var_new:0.360
# batch i:66, episode_len:12
# kl:0.01578,lr_multiplier:0.444,loss:4.165849208831787,entropy:3.573028564453125,explained_var_old:0.360,explained_var_new:0.449
# batch i:67, episode_len:10
# kl:0.02207,lr_multiplier:0.444,loss:4.27407169342041,entropy:3.638518810272217,explained_var_old:0.316,explained_var_new:0.342
# batch i:68, episode_len:14
# kl:0.01769,lr_multiplier:0.444,loss:4.16684103012085,entropy:3.547748327255249,explained_var_old:0.352,explained_var_new:0.407
# batch i:69, episode_len:11
# kl:0.02095,lr_multiplier:0.444,loss:4.098104953765869,entropy:3.549259901046753,explained_var_old:0.392,explained_var_new:0.430
# batch i:70, episode_len:20
# kl:0.01370,lr_multiplier:0.444,loss:4.175376892089844,entropy:3.643296241760254,explained_var_old:0.345,explained_var_new:0.410
# batch i:71, episode_len:14
# kl:0.01250,lr_multiplier:0.444,loss:4.14493989944458,entropy:3.6270480155944824,explained_var_old:0.336,explained_var_new:0.435
# batch i:72, episode_len:12
# kl:0.01996,lr_multiplier:0.444,loss:4.157558917999268,entropy:3.5617706775665283,explained_var_old:0.327,explained_var_new:0.368
# batch i:73, episode_len:11
# kl:0.02048,lr_multiplier:0.444,loss:4.137748718261719,entropy:3.592730760574341,explained_var_old:0.348,explained_var_new:0.408
# batch i:74, episode_len:16
# kl:0.01239,lr_multiplier:0.444,loss:4.155552387237549,entropy:3.595236301422119,explained_var_old:0.417,explained_var_new:0.456
# batch i:75, episode_len:15
# kl:0.01607,lr_multiplier:0.444,loss:4.076284408569336,entropy:3.562075614929199,explained_var_old:0.440,explained_var_new:0.490
# batch i:76, episode_len:20
# kl:0.01691,lr_multiplier:0.444,loss:4.079775333404541,entropy:3.5147409439086914,explained_var_old:0.375,explained_var_new:0.428
# batch i:77, episode_len:9
# kl:0.01355,lr_multiplier:0.444,loss:4.138715744018555,entropy:3.554884910583496,explained_var_old:0.344,explained_var_new:0.397
# batch i:78, episode_len:13
# kl:0.01846,lr_multiplier:0.444,loss:4.144253730773926,entropy:3.5373551845550537,explained_var_old:0.350,explained_var_new:0.429
# batch i:79, episode_len:21
# kl:0.01509,lr_multiplier:0.444,loss:4.057098865509033,entropy:3.4982573986053467,explained_var_old:0.359,explained_var_new:0.415
# batch i:80, episode_len:11
# kl:0.01985,lr_multiplier:0.444,loss:3.984591484069824,entropy:3.4987709522247314,explained_var_old:0.425,explained_var_new:0.462
# batch i:81, episode_len:11
# kl:0.01643,lr_multiplier:0.444,loss:4.132767200469971,entropy:3.56758189201355,explained_var_old:0.370,explained_var_new:0.427
# batch i:82, episode_len:19
# kl:0.01968,lr_multiplier:0.444,loss:4.092195510864258,entropy:3.479357957839966,explained_var_old:0.330,explained_var_new:0.411
# batch i:83, episode_len:16
# kl:0.02016,lr_multiplier:0.444,loss:4.049345016479492,entropy:3.4254119396209717,explained_var_old:0.301,explained_var_new:0.389
# batch i:84, episode_len:14
# kl:0.02779,lr_multiplier:0.444,loss:3.9587018489837646,entropy:3.427346706390381,explained_var_old:0.407,explained_var_new:0.447
# batch i:85, episode_len:9
# kl:0.02547,lr_multiplier:0.444,loss:4.0564799308776855,entropy:3.3552560806274414,explained_var_old:0.303,explained_var_new:0.375
# batch i:86, episode_len:9
# kl:0.03986,lr_multiplier:0.444,loss:3.9168648719787598,entropy:3.36118745803833,explained_var_old:0.371,explained_var_new:0.418
# batch i:87, episode_len:9
# kl:0.02149,lr_multiplier:0.444,loss:3.890728712081909,entropy:3.3723561763763428,explained_var_old:0.354,explained_var_new:0.432
# batch i:88, episode_len:11
# kl:0.02655,lr_multiplier:0.444,loss:3.879885673522949,entropy:3.3356356620788574,explained_var_old:0.332,explained_var_new:0.378
# batch i:89, episode_len:10
# kl:0.02724,lr_multiplier:0.444,loss:3.846414566040039,entropy:3.26271915435791,explained_var_old:0.364,explained_var_new:0.435
# batch i:90, episode_len:16
# kl:0.03344,lr_multiplier:0.444,loss:3.8860349655151367,entropy:3.3818345069885254,explained_var_old:0.383,explained_var_new:0.429
# batch i:91, episode_len:15
# kl:0.02100,lr_multiplier:0.444,loss:3.8586440086364746,entropy:3.327457904815674,explained_var_old:0.398,explained_var_new:0.446
# batch i:92, episode_len:10
# kl:0.03228,lr_multiplier:0.444,loss:3.8672614097595215,entropy:3.2091012001037598,explained_var_old:0.349,explained_var_new:0.413
# batch i:93, episode_len:10
# kl:0.02968,lr_multiplier:0.444,loss:3.852971315383911,entropy:3.2947475910186768,explained_var_old:0.384,explained_var_new:0.424
# batch i:94, episode_len:20
# kl:0.01854,lr_multiplier:0.444,loss:3.800814628601074,entropy:3.213191032409668,explained_var_old:0.336,explained_var_new:0.411
# batch i:95, episode_len:11
# kl:0.02029,lr_multiplier:0.444,loss:3.828336238861084,entropy:3.2556583881378174,explained_var_old:0.376,explained_var_new:0.415
# batch i:96, episode_len:17
# kl:0.01335,lr_multiplier:0.444,loss:3.9087138175964355,entropy:3.2656471729278564,explained_var_old:0.300,explained_var_new:0.349
# batch i:97, episode_len:14
# kl:0.01653,lr_multiplier:0.444,loss:3.9383087158203125,entropy:3.3275017738342285,explained_var_old:0.279,explained_var_new:0.358
# batch i:98, episode_len:14
# kl:0.02811,lr_multiplier:0.444,loss:3.8488149642944336,entropy:3.189042091369629,explained_var_old:0.282,explained_var_new:0.354
# batch i:99, episode_len:11
# kl:0.03017,lr_multiplier:0.444,loss:3.724705696105957,entropy:3.2072792053222656,explained_var_old:0.368,explained_var_new:0.452
# batch i:100, episode_len:12
# kl:0.03749,lr_multiplier:0.444,loss:3.753455638885498,entropy:3.226276159286499,explained_var_old:0.344,explained_var_new:0.425
# current self-play batch: 100
# num_playouts:1000, win: 9, lose: 1, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:7
# kl:0.02933,lr_multiplier:0.444,loss:3.777454376220703,entropy:3.206982374191284,explained_var_old:0.362,explained_var_new:0.410
# batch i:102, episode_len:13
# kl:0.04306,lr_multiplier:0.296,loss:3.719874382019043,entropy:3.1642589569091797,explained_var_old:0.327,explained_var_new:0.411
# batch i:103, episode_len:13
# kl:0.02736,lr_multiplier:0.296,loss:3.906975746154785,entropy:3.274369478225708,explained_var_old:0.273,explained_var_new:0.341
# batch i:104, episode_len:19
# kl:0.01391,lr_multiplier:0.296,loss:3.8312203884124756,entropy:3.184537410736084,explained_var_old:0.310,explained_var_new:0.332
# batch i:105, episode_len:24
# kl:0.02856,lr_multiplier:0.296,loss:3.847628593444824,entropy:3.2070517539978027,explained_var_old:0.311,explained_var_new:0.361
# batch i:106, episode_len:14
# kl:0.02512,lr_multiplier:0.296,loss:3.8568806648254395,entropy:3.2543210983276367,explained_var_old:0.300,explained_var_new:0.360
# batch i:107, episode_len:9
# kl:0.03363,lr_multiplier:0.296,loss:3.8219640254974365,entropy:3.093963623046875,explained_var_old:0.263,explained_var_new:0.327
# batch i:108, episode_len:11
# kl:0.01543,lr_multiplier:0.296,loss:3.78651762008667,entropy:3.181288719177246,explained_var_old:0.314,explained_var_new:0.352
# batch i:109, episode_len:14
# kl:0.01653,lr_multiplier:0.296,loss:3.8286192417144775,entropy:3.150080442428589,explained_var_old:0.219,explained_var_new:0.282
# batch i:110, episode_len:20
# kl:0.01918,lr_multiplier:0.296,loss:3.7804388999938965,entropy:3.115088939666748,explained_var_old:0.289,explained_var_new:0.339
# batch i:111, episode_len:10
# kl:0.01289,lr_multiplier:0.296,loss:3.667050838470459,entropy:3.1963555812835693,explained_var_old:0.380,explained_var_new:0.426
# batch i:112, episode_len:11
# kl:0.02371,lr_multiplier:0.296,loss:3.724527597427368,entropy:3.1313540935516357,explained_var_old:0.341,explained_var_new:0.399
# batch i:113, episode_len:20
# kl:0.03064,lr_multiplier:0.296,loss:3.7132480144500732,entropy:3.110212802886963,explained_var_old:0.361,explained_var_new:0.401
# batch i:114, episode_len:12
# kl:0.01330,lr_multiplier:0.296,loss:3.685424327850342,entropy:3.090205430984497,explained_var_old:0.333,explained_var_new:0.389
# batch i:115, episode_len:11
# kl:0.02144,lr_multiplier:0.296,loss:3.7416439056396484,entropy:3.1327900886535645,explained_var_old:0.272,explained_var_new:0.368
# batch i:116, episode_len:9
# kl:0.01960,lr_multiplier:0.296,loss:3.7377853393554688,entropy:3.1504340171813965,explained_var_old:0.285,explained_var_new:0.352
# batch i:117, episode_len:14
# kl:0.01282,lr_multiplier:0.296,loss:3.7275681495666504,entropy:3.1068174839019775,explained_var_old:0.303,explained_var_new:0.351
# batch i:118, episode_len:9
# kl:0.01870,lr_multiplier:0.296,loss:3.6881825923919678,entropy:3.0321033000946045,explained_var_old:0.337,explained_var_new:0.372
# batch i:119, episode_len:14
# kl:0.01882,lr_multiplier:0.296,loss:3.7791521549224854,entropy:3.13405179977417,explained_var_old:0.295,explained_var_new:0.331
# batch i:120, episode_len:8
# kl:0.01076,lr_multiplier:0.296,loss:3.6501893997192383,entropy:3.073181629180908,explained_var_old:0.334,explained_var_new:0.367
# batch i:121, episode_len:7
# kl:0.01327,lr_multiplier:0.296,loss:3.643432855606079,entropy:3.037970781326294,explained_var_old:0.364,explained_var_new:0.408
# batch i:122, episode_len:19
# kl:0.01484,lr_multiplier:0.296,loss:3.669166326522827,entropy:3.0416455268859863,explained_var_old:0.287,explained_var_new:0.322
# batch i:123, episode_len:12
# kl:0.01135,lr_multiplier:0.296,loss:3.6341662406921387,entropy:3.004925012588501,explained_var_old:0.319,explained_var_new:0.351
# batch i:124, episode_len:18
# kl:0.01367,lr_multiplier:0.296,loss:3.6626248359680176,entropy:3.009875774383545,explained_var_old:0.310,explained_var_new:0.352
# batch i:125, episode_len:16
# kl:0.01084,lr_multiplier:0.296,loss:3.618058443069458,entropy:3.033163070678711,explained_var_old:0.369,explained_var_new:0.389
# batch i:126, episode_len:12
# kl:0.01238,lr_multiplier:0.296,loss:3.5838170051574707,entropy:2.9586055278778076,explained_var_old:0.330,explained_var_new:0.363
# batch i:127, episode_len:14
# kl:0.01691,lr_multiplier:0.296,loss:3.5574002265930176,entropy:2.976271390914917,explained_var_old:0.341,explained_var_new:0.374
# batch i:128, episode_len:7
# kl:0.01726,lr_multiplier:0.296,loss:3.475209951400757,entropy:2.94094181060791,explained_var_old:0.425,explained_var_new:0.456
# batch i:129, episode_len:15
# kl:0.01893,lr_multiplier:0.296,loss:3.476339817047119,entropy:2.8442115783691406,explained_var_old:0.256,explained_var_new:0.331
# batch i:130, episode_len:11
# kl:0.02288,lr_multiplier:0.296,loss:3.5914127826690674,entropy:2.898374319076538,explained_var_old:0.298,explained_var_new:0.350
# batch i:131, episode_len:11
# kl:0.01553,lr_multiplier:0.296,loss:3.590125799179077,entropy:3.0889737606048584,explained_var_old:0.371,explained_var_new:0.406
# batch i:132, episode_len:7
# kl:0.02651,lr_multiplier:0.296,loss:3.569398880004883,entropy:3.023273468017578,explained_var_old:0.344,explained_var_new:0.387
# batch i:133, episode_len:13
# kl:0.01894,lr_multiplier:0.296,loss:3.492251396179199,entropy:2.840013265609741,explained_var_old:0.277,explained_var_new:0.327
# batch i:134, episode_len:8
# kl:0.02506,lr_multiplier:0.296,loss:3.490006923675537,entropy:2.821357011795044,explained_var_old:0.348,explained_var_new:0.382
# batch i:135, episode_len:14
# kl:0.02666,lr_multiplier:0.296,loss:3.469611167907715,entropy:2.777089834213257,explained_var_old:0.285,explained_var_new:0.329
# batch i:136, episode_len:7
# kl:0.03950,lr_multiplier:0.296,loss:3.4850025177001953,entropy:2.936979293823242,explained_var_old:0.317,explained_var_new:0.369
# batch i:137, episode_len:7
# kl:0.02714,lr_multiplier:0.296,loss:3.4677300453186035,entropy:2.9764747619628906,explained_var_old:0.319,explained_var_new:0.396
# batch i:138, episode_len:12
# kl:0.02402,lr_multiplier:0.296,loss:3.495185136795044,entropy:2.8939921855926514,explained_var_old:0.324,explained_var_new:0.407
# batch i:139, episode_len:21
# kl:0.02119,lr_multiplier:0.296,loss:3.496609687805176,entropy:2.849583387374878,explained_var_old:0.308,explained_var_new:0.324
# batch i:140, episode_len:10
# kl:0.02162,lr_multiplier:0.296,loss:3.557304620742798,entropy:2.8259429931640625,explained_var_old:0.281,explained_var_new:0.333
# batch i:141, episode_len:12
# kl:0.03193,lr_multiplier:0.296,loss:3.516129732131958,entropy:2.9321656227111816,explained_var_old:0.300,explained_var_new:0.352
# batch i:142, episode_len:10
# kl:0.01787,lr_multiplier:0.296,loss:3.5942225456237793,entropy:2.919891595840454,explained_var_old:0.283,explained_var_new:0.344
# batch i:143, episode_len:7
# kl:0.02301,lr_multiplier:0.296,loss:3.434617757797241,entropy:2.8032662868499756,explained_var_old:0.327,explained_var_new:0.341
# batch i:144, episode_len:9
# kl:0.02752,lr_multiplier:0.296,loss:3.528897762298584,entropy:2.868973970413208,explained_var_old:0.278,explained_var_new:0.328
# batch i:145, episode_len:7
# kl:0.01894,lr_multiplier:0.296,loss:3.487499713897705,entropy:2.8980324268341064,explained_var_old:0.316,explained_var_new:0.343
# batch i:146, episode_len:14
# kl:0.01872,lr_multiplier:0.296,loss:3.3712871074676514,entropy:2.8182213306427,explained_var_old:0.325,explained_var_new:0.361
# batch i:147, episode_len:9
# kl:0.01442,lr_multiplier:0.296,loss:3.4725704193115234,entropy:2.7277634143829346,explained_var_old:0.249,explained_var_new:0.300
# batch i:148, episode_len:12
# kl:0.02112,lr_multiplier:0.296,loss:3.486783027648926,entropy:2.7652125358581543,explained_var_old:0.280,explained_var_new:0.328
# batch i:149, episode_len:21
# kl:0.01175,lr_multiplier:0.296,loss:3.371938943862915,entropy:2.815431833267212,explained_var_old:0.372,explained_var_new:0.414
# batch i:150, episode_len:12
# kl:0.02451,lr_multiplier:0.296,loss:3.395573377609253,entropy:2.802699565887451,explained_var_old:0.326,explained_var_new:0.359
# current self-play batch: 150
# num_playouts:1000, win: 8, lose: 2, tie:0
# batch i:151, episode_len:9
# kl:0.01716,lr_multiplier:0.296,loss:3.4332456588745117,entropy:2.82985782623291,explained_var_old:0.357,explained_var_new:0.389
# batch i:152, episode_len:9
# kl:0.02088,lr_multiplier:0.296,loss:3.3953912258148193,entropy:2.8423452377319336,explained_var_old:0.340,explained_var_new:0.378
# batch i:153, episode_len:7
# kl:0.02689,lr_multiplier:0.296,loss:3.4187419414520264,entropy:2.789461612701416,explained_var_old:0.321,explained_var_new:0.365
# batch i:154, episode_len:11
# kl:0.02240,lr_multiplier:0.296,loss:3.32930064201355,entropy:2.757596254348755,explained_var_old:0.359,explained_var_new:0.392
# batch i:155, episode_len:13
# kl:0.03145,lr_multiplier:0.296,loss:3.3814640045166016,entropy:2.806298017501831,explained_var_old:0.326,explained_var_new:0.364
# batch i:156, episode_len:14
# kl:0.01922,lr_multiplier:0.296,loss:3.2850005626678467,entropy:2.6871025562286377,explained_var_old:0.381,explained_var_new:0.421
# batch i:157, episode_len:13
# kl:0.03642,lr_multiplier:0.296,loss:3.4192700386047363,entropy:2.7533881664276123,explained_var_old:0.330,explained_var_new:0.363
# batch i:158, episode_len:7
# kl:0.01970,lr_multiplier:0.296,loss:3.3378634452819824,entropy:2.7602202892303467,explained_var_old:0.332,explained_var_new:0.370
# batch i:159, episode_len:10
# kl:0.01696,lr_multiplier:0.296,loss:3.3485522270202637,entropy:2.6827218532562256,explained_var_old:0.313,explained_var_new:0.343
# batch i:160, episode_len:17
# kl:0.02724,lr_multiplier:0.296,loss:3.420656681060791,entropy:2.711993455886841,explained_var_old:0.253,explained_var_new:0.310
# batch i:161, episode_len:8
# kl:0.02561,lr_multiplier:0.296,loss:3.3653759956359863,entropy:2.7607054710388184,explained_var_old:0.317,explained_var_new:0.360
# batch i:162, episode_len:9
# kl:0.01375,lr_multiplier:0.296,loss:3.2400155067443848,entropy:2.650303602218628,explained_var_old:0.341,explained_var_new:0.387
# batch i:163, episode_len:10
# kl:0.02352,lr_multiplier:0.296,loss:3.379302978515625,entropy:2.740279197692871,explained_var_old:0.317,explained_var_new:0.378
# batch i:164, episode_len:11
# kl:0.01872,lr_multiplier:0.296,loss:3.254631996154785,entropy:2.682650327682495,explained_var_old:0.329,explained_var_new:0.373
# batch i:165, episode_len:11
# kl:0.01840,lr_multiplier:0.296,loss:3.2055366039276123,entropy:2.7067501544952393,explained_var_old:0.363,explained_var_new:0.402
# batch i:166, episode_len:11
# kl:0.02566,lr_multiplier:0.296,loss:3.3372621536254883,entropy:2.6982040405273438,explained_var_old:0.283,explained_var_new:0.344
# batch i:167, episode_len:8
# kl:0.02404,lr_multiplier:0.296,loss:3.262723445892334,entropy:2.583545684814453,explained_var_old:0.267,explained_var_new:0.311
# batch i:168, episode_len:13
# kl:0.02122,lr_multiplier:0.296,loss:3.260190725326538,entropy:2.690436363220215,explained_var_old:0.367,explained_var_new:0.423
# batch i:169, episode_len:9
# kl:0.01552,lr_multiplier:0.296,loss:3.3208773136138916,entropy:2.7481415271759033,explained_var_old:0.326,explained_var_new:0.354
# batch i:170, episode_len:13
# kl:0.03071,lr_multiplier:0.296,loss:3.2375333309173584,entropy:2.6589338779449463,explained_var_old:0.351,explained_var_new:0.398
# batch i:171, episode_len:7
# kl:0.01961,lr_multiplier:0.296,loss:3.2941699028015137,entropy:2.645447015762329,explained_var_old:0.337,explained_var_new:0.386
# batch i:172, episode_len:9
# kl:0.02499,lr_multiplier:0.296,loss:3.2066774368286133,entropy:2.5588297843933105,explained_var_old:0.298,explained_var_new:0.353
# batch i:173, episode_len:8
# kl:0.02142,lr_multiplier:0.296,loss:3.318905830383301,entropy:2.516348361968994,explained_var_old:0.257,explained_var_new:0.302
# batch i:174, episode_len:12
# kl:0.03466,lr_multiplier:0.296,loss:3.1839101314544678,entropy:2.620076894760132,explained_var_old:0.323,explained_var_new:0.364
# batch i:175, episode_len:9
# kl:0.02195,lr_multiplier:0.296,loss:3.3306784629821777,entropy:2.6903226375579834,explained_var_old:0.294,explained_var_new:0.342
# batch i:176, episode_len:10
# kl:0.02936,lr_multiplier:0.296,loss:3.2521538734436035,entropy:2.694766044616699,explained_var_old:0.365,explained_var_new:0.410
# batch i:177, episode_len:9
# kl:0.01512,lr_multiplier:0.296,loss:3.2365262508392334,entropy:2.6833746433258057,explained_var_old:0.333,explained_var_new:0.374
# batch i:178, episode_len:9
# kl:0.01885,lr_multiplier:0.296,loss:3.177823543548584,entropy:2.524801015853882,explained_var_old:0.361,explained_var_new:0.404
# batch i:179, episode_len:11
# kl:0.02620,lr_multiplier:0.296,loss:3.166970729827881,entropy:2.5524423122406006,explained_var_old:0.356,explained_var_new:0.390
# batch i:180, episode_len:9
# kl:0.03376,lr_multiplier:0.296,loss:3.1854052543640137,entropy:2.640028715133667,explained_var_old:0.337,explained_var_new:0.375
# batch i:181, episode_len:13
# kl:0.02026,lr_multiplier:0.296,loss:3.1370959281921387,entropy:2.5095345973968506,explained_var_old:0.304,explained_var_new:0.346
# batch i:182, episode_len:17
# kl:0.01444,lr_multiplier:0.296,loss:3.302394390106201,entropy:2.6871819496154785,explained_var_old:0.295,explained_var_new:0.338
# batch i:183, episode_len:11
# kl:0.02921,lr_multiplier:0.296,loss:3.1600840091705322,entropy:2.514678955078125,explained_var_old:0.357,explained_var_new:0.389
# batch i:184, episode_len:9
# kl:0.02875,lr_multiplier:0.296,loss:3.1628847122192383,entropy:2.5781497955322266,explained_var_old:0.357,explained_var_new:0.400
# batch i:185, episode_len:15
# kl:0.03941,lr_multiplier:0.296,loss:3.1006739139556885,entropy:2.573701858520508,explained_var_old:0.374,explained_var_new:0.408
# batch i:186, episode_len:11
# kl:0.01998,lr_multiplier:0.296,loss:3.257749557495117,entropy:2.5038018226623535,explained_var_old:0.218,explained_var_new:0.279
# batch i:187, episode_len:7
# kl:0.02586,lr_multiplier:0.296,loss:3.126964569091797,entropy:2.5572690963745117,explained_var_old:0.298,explained_var_new:0.357
# batch i:188, episode_len:7
# kl:0.03229,lr_multiplier:0.296,loss:3.051146984100342,entropy:2.4527883529663086,explained_var_old:0.355,explained_var_new:0.413
# batch i:189, episode_len:9
# kl:0.03926,lr_multiplier:0.296,loss:3.2185709476470947,entropy:2.5547256469726562,explained_var_old:0.272,explained_var_new:0.306
# batch i:190, episode_len:11
# kl:0.02235,lr_multiplier:0.296,loss:3.180323600769043,entropy:2.560328245162964,explained_var_old:0.263,explained_var_new:0.317
# batch i:191, episode_len:9
# kl:0.03690,lr_multiplier:0.296,loss:3.0036964416503906,entropy:2.4284393787384033,explained_var_old:0.386,explained_var_new:0.418
# batch i:192, episode_len:10
# kl:0.03571,lr_multiplier:0.296,loss:3.0779147148132324,entropy:2.5187764167785645,explained_var_old:0.395,explained_var_new:0.430
# batch i:193, episode_len:11
# kl:0.02473,lr_multiplier:0.296,loss:3.1354820728302,entropy:2.4566311836242676,explained_var_old:0.256,explained_var_new:0.347
# batch i:194, episode_len:14
# kl:0.02442,lr_multiplier:0.296,loss:3.0415468215942383,entropy:2.469665050506592,explained_var_old:0.359,explained_var_new:0.383
# batch i:195, episode_len:13
# kl:0.02267,lr_multiplier:0.296,loss:3.049722194671631,entropy:2.457059383392334,explained_var_old:0.343,explained_var_new:0.378
# batch i:196, episode_len:19
# kl:0.03344,lr_multiplier:0.296,loss:3.0782718658447266,entropy:2.5503010749816895,explained_var_old:0.360,explained_var_new:0.415
# batch i:197, episode_len:13
# kl:0.01316,lr_multiplier:0.296,loss:3.0665786266326904,entropy:2.456284761428833,explained_var_old:0.390,explained_var_new:0.421
# batch i:198, episode_len:14
# kl:0.02983,lr_multiplier:0.296,loss:3.0624473094940186,entropy:2.458517551422119,explained_var_old:0.344,explained_var_new:0.387
# batch i:199, episode_len:10
# kl:0.01962,lr_multiplier:0.296,loss:3.086824417114258,entropy:2.490797758102417,explained_var_old:0.328,explained_var_new:0.376
# batch i:200, episode_len:7
# kl:0.01663,lr_multiplier:0.296,loss:3.0226526260375977,entropy:2.373971700668335,explained_var_old:0.245,explained_var_new:0.345
# current self-play batch: 200
# num_playouts:1000, win: 10, lose: 0, tie:0
# 发现新的最优策略，进行策略更新
# batch i:201, episode_len:9
# kl:0.02535,lr_multiplier:0.296,loss:3.074798107147217,entropy:2.5193026065826416,explained_var_old:0.381,explained_var_new:0.416
# batch i:202, episode_len:11
# kl:0.03313,lr_multiplier:0.296,loss:3.066311836242676,entropy:2.433272123336792,explained_var_old:0.325,explained_var_new:0.359
# batch i:203, episode_len:8
# kl:0.01655,lr_multiplier:0.296,loss:2.9633843898773193,entropy:2.394503355026245,explained_var_old:0.376,explained_var_new:0.424
# batch i:204, episode_len:9
# kl:0.02352,lr_multiplier:0.296,loss:3.001732110977173,entropy:2.514357566833496,explained_var_old:0.400,explained_var_new:0.452
# batch i:205, episode_len:9
# kl:0.02598,lr_multiplier:0.296,loss:2.8639211654663086,entropy:2.274956703186035,explained_var_old:0.370,explained_var_new:0.401
# batch i:206, episode_len:11
# kl:0.01811,lr_multiplier:0.296,loss:3.0024640560150146,entropy:2.342878818511963,explained_var_old:0.318,explained_var_new:0.359
# batch i:207, episode_len:9
# kl:0.02100,lr_multiplier:0.296,loss:3.008817195892334,entropy:2.39986515045166,explained_var_old:0.343,explained_var_new:0.381
# batch i:208, episode_len:9
# kl:0.01715,lr_multiplier:0.296,loss:3.0944063663482666,entropy:2.4268200397491455,explained_var_old:0.284,explained_var_new:0.322
# batch i:209, episode_len:9
# kl:0.02162,lr_multiplier:0.296,loss:3.04370379447937,entropy:2.418104887008667,explained_var_old:0.339,explained_var_new:0.369
# batch i:210, episode_len:12
# kl:0.02369,lr_multiplier:0.296,loss:2.96389102935791,entropy:2.409581422805786,explained_var_old:0.372,explained_var_new:0.431
# batch i:211, episode_len:11
# kl:0.04148,lr_multiplier:0.198,loss:3.0688745975494385,entropy:2.400381565093994,explained_var_old:0.265,explained_var_new:0.326
# batch i:212, episode_len:13
# kl:0.01532,lr_multiplier:0.198,loss:2.923931360244751,entropy:2.4096410274505615,explained_var_old:0.378,explained_var_new:0.417
# batch i:213, episode_len:8
# kl:0.01349,lr_multiplier:0.198,loss:2.9961163997650146,entropy:2.410299777984619,explained_var_old:0.397,explained_var_new:0.409
# batch i:214, episode_len:9
# kl:0.01825,lr_multiplier:0.198,loss:2.899827718734741,entropy:2.219346284866333,explained_var_old:0.314,explained_var_new:0.372
# batch i:215, episode_len:19
# kl:0.01596,lr_multiplier:0.198,loss:3.0304348468780518,entropy:2.4293010234832764,explained_var_old:0.358,explained_var_new:0.380
# batch i:216, episode_len:10
# kl:0.00653,lr_multiplier:0.296,loss:2.9387359619140625,entropy:2.3467628955841064,explained_var_old:0.357,explained_var_new:0.383
# batch i:217, episode_len:11
# kl:0.02940,lr_multiplier:0.296,loss:2.8937575817108154,entropy:2.2823758125305176,explained_var_old:0.355,explained_var_new:0.401
# batch i:218, episode_len:11
# kl:0.01710,lr_multiplier:0.296,loss:2.977616310119629,entropy:2.410770893096924,explained_var_old:0.339,explained_var_new:0.377
# batch i:219, episode_len:10
# kl:0.02127,lr_multiplier:0.296,loss:3.038308620452881,entropy:2.4227161407470703,explained_var_old:0.256,explained_var_new:0.299
# batch i:220, episode_len:12
# kl:0.02503,lr_multiplier:0.296,loss:2.8818814754486084,entropy:2.2590746879577637,explained_var_old:0.357,explained_var_new:0.410
# batch i:221, episode_len:11
# kl:0.02041,lr_multiplier:0.296,loss:3.0289392471313477,entropy:2.3467772006988525,explained_var_old:0.278,explained_var_new:0.317
# batch i:222, episode_len:7
# kl:0.02116,lr_multiplier:0.296,loss:2.8449761867523193,entropy:2.361767053604126,explained_var_old:0.422,explained_var_new:0.489
# batch i:223, episode_len:11
# kl:0.01327,lr_multiplier:0.296,loss:2.931154727935791,entropy:2.3031413555145264,explained_var_old:0.329,explained_var_new:0.356
# batch i:224, episode_len:10
# kl:0.01766,lr_multiplier:0.296,loss:2.9697012901306152,entropy:2.4057564735412598,explained_var_old:0.349,explained_var_new:0.396
# batch i:225, episode_len:12
# kl:0.01676,lr_multiplier:0.296,loss:2.9649617671966553,entropy:2.256089687347412,explained_var_old:0.267,explained_var_new:0.306
# batch i:226, episode_len:7
# kl:0.01786,lr_multiplier:0.296,loss:3.037294626235962,entropy:2.376983880996704,explained_var_old:0.327,explained_var_new:0.348
# batch i:227, episode_len:8
# kl:0.01592,lr_multiplier:0.296,loss:2.7829439640045166,entropy:2.2885711193084717,explained_var_old:0.392,explained_var_new:0.422
# batch i:228, episode_len:10
# kl:0.02534,lr_multiplier:0.296,loss:2.946349859237671,entropy:2.3006081581115723,explained_var_old:0.276,explained_var_new:0.327
# batch i:229, episode_len:14
# kl:0.02250,lr_multiplier:0.296,loss:3.0119173526763916,entropy:2.352372169494629,explained_var_old:0.259,explained_var_new:0.302
# batch i:230, episode_len:11
# kl:0.01625,lr_multiplier:0.296,loss:2.9814047813415527,entropy:2.2437219619750977,explained_var_old:0.210,explained_var_new:0.290
# batch i:231, episode_len:9
# kl:0.02312,lr_multiplier:0.296,loss:2.966020107269287,entropy:2.359487295150757,explained_var_old:0.291,explained_var_new:0.341
# batch i:232, episode_len:9
# kl:0.02515,lr_multiplier:0.296,loss:2.9213500022888184,entropy:2.3282101154327393,explained_var_old:0.340,explained_var_new:0.384
# batch i:233, episode_len:10
# kl:0.01682,lr_multiplier:0.296,loss:2.976879835128784,entropy:2.3391058444976807,explained_var_old:0.282,explained_var_new:0.335
# batch i:234, episode_len:12
# kl:0.02271,lr_multiplier:0.296,loss:2.933300495147705,entropy:2.260554790496826,explained_var_old:0.294,explained_var_new:0.337
# batch i:235, episode_len:8
# kl:0.02802,lr_multiplier:0.296,loss:2.934558868408203,entropy:2.2827377319335938,explained_var_old:0.296,explained_var_new:0.335
# batch i:236, episode_len:13
# kl:0.02290,lr_multiplier:0.296,loss:2.877932548522949,entropy:2.2704389095306396,explained_var_old:0.333,explained_var_new:0.356
# batch i:237, episode_len:7
# kl:0.02417,lr_multiplier:0.296,loss:2.864283561706543,entropy:2.2083160877227783,explained_var_old:0.300,explained_var_new:0.344
# batch i:238, episode_len:12
# kl:0.01922,lr_multiplier:0.296,loss:2.813992977142334,entropy:2.2059860229492188,explained_var_old:0.339,explained_var_new:0.388
# batch i:239, episode_len:7
# kl:0.01590,lr_multiplier:0.296,loss:2.961866855621338,entropy:2.327144145965576,explained_var_old:0.273,explained_var_new:0.331
# batch i:240, episode_len:12
# kl:0.01554,lr_multiplier:0.296,loss:2.800352096557617,entropy:2.1639766693115234,explained_var_old:0.302,explained_var_new:0.333
# batch i:241, episode_len:7
# kl:0.01520,lr_multiplier:0.296,loss:2.8702149391174316,entropy:2.232860565185547,explained_var_old:0.312,explained_var_new:0.342
# batch i:242, episode_len:11
# kl:0.02005,lr_multiplier:0.296,loss:2.9078123569488525,entropy:2.273135185241699,explained_var_old:0.265,explained_var_new:0.308
# batch i:243, episode_len:7
# kl:0.01619,lr_multiplier:0.296,loss:2.8563404083251953,entropy:2.2120842933654785,explained_var_old:0.302,explained_var_new:0.337
# batch i:244, episode_len:11
# kl:0.01921,lr_multiplier:0.296,loss:2.802626609802246,entropy:2.108891487121582,explained_var_old:0.328,explained_var_new:0.369
# batch i:245, episode_len:9
# kl:0.01513,lr_multiplier:0.296,loss:2.7659852504730225,entropy:2.1948909759521484,explained_var_old:0.354,explained_var_new:0.393
# batch i:246, episode_len:11
# kl:0.01665,lr_multiplier:0.296,loss:2.838045835494995,entropy:2.2588417530059814,explained_var_old:0.349,explained_var_new:0.368
# batch i:247, episode_len:10
# kl:0.01729,lr_multiplier:0.296,loss:2.79007887840271,entropy:2.1244630813598633,explained_var_old:0.309,explained_var_new:0.343
# batch i:248, episode_len:7
# kl:0.02404,lr_multiplier:0.296,loss:2.8344509601593018,entropy:2.260918140411377,explained_var_old:0.326,explained_var_new:0.375
# batch i:249, episode_len:7
# kl:0.02299,lr_multiplier:0.296,loss:2.938993453979492,entropy:2.2918171882629395,explained_var_old:0.298,explained_var_new:0.323
# batch i:250, episode_len:9
# kl:0.02499,lr_multiplier:0.296,loss:2.7822093963623047,entropy:2.1455740928649902,explained_var_old:0.320,explained_var_new:0.349
# current self-play batch: 250
# num_playouts:2000, win: 8, lose: 2, tie:0
# 发现新的最优策略，进行策略更新
# batch i:251, episode_len:13
# kl:0.01441,lr_multiplier:0.296,loss:2.9272849559783936,entropy:2.2720553874969482,explained_var_old:0.295,explained_var_new:0.333
# batch i:252, episode_len:8
# kl:0.02416,lr_multiplier:0.296,loss:2.7053747177124023,entropy:2.145009756088257,explained_var_old:0.417,explained_var_new:0.451
# batch i:253, episode_len:12
# kl:0.01727,lr_multiplier:0.296,loss:2.792990207672119,entropy:2.191939115524292,explained_var_old:0.372,explained_var_new:0.414
# batch i:254, episode_len:7
# kl:0.01774,lr_multiplier:0.296,loss:2.7229063510894775,entropy:2.192140579223633,explained_var_old:0.393,explained_var_new:0.432
# batch i:255, episode_len:9
# kl:0.01427,lr_multiplier:0.296,loss:2.8101651668548584,entropy:2.175588607788086,explained_var_old:0.325,explained_var_new:0.357
# batch i:256, episode_len:7
# kl:0.02577,lr_multiplier:0.296,loss:2.7632241249084473,entropy:2.2580909729003906,explained_var_old:0.346,explained_var_new:0.396
# batch i:257, episode_len:10
# kl:0.02020,lr_multiplier:0.296,loss:2.8083133697509766,entropy:2.1659271717071533,explained_var_old:0.289,explained_var_new:0.346
# batch i:258, episode_len:7
# kl:0.01937,lr_multiplier:0.296,loss:2.8587207794189453,entropy:2.1592605113983154,explained_var_old:0.272,explained_var_new:0.301
# batch i:259, episode_len:7
# kl:0.02151,lr_multiplier:0.296,loss:2.807614326477051,entropy:2.111384868621826,explained_var_old:0.284,explained_var_new:0.308
# batch i:260, episode_len:11
# kl:0.01593,lr_multiplier:0.296,loss:2.7798266410827637,entropy:2.1507980823516846,explained_var_old:0.365,explained_var_new:0.400
# batch i:261, episode_len:9
# kl:0.02348,lr_multiplier:0.296,loss:2.700462579727173,entropy:2.0890274047851562,explained_var_old:0.343,explained_var_new:0.388
# batch i:262, episode_len:10
# kl:0.01529,lr_multiplier:0.296,loss:2.758049488067627,entropy:2.2240636348724365,explained_var_old:0.347,explained_var_new:0.376
# batch i:263, episode_len:10
# kl:0.01781,lr_multiplier:0.296,loss:2.81693696975708,entropy:2.172353744506836,explained_var_old:0.256,explained_var_new:0.316
# batch i:264, episode_len:9
# kl:0.01689,lr_multiplier:0.296,loss:2.770414352416992,entropy:2.1449735164642334,explained_var_old:0.297,explained_var_new:0.335
# batch i:265, episode_len:7
# kl:0.02018,lr_multiplier:0.296,loss:2.7737913131713867,entropy:2.1538872718811035,explained_var_old:0.334,explained_var_new:0.374
# batch i:266, episode_len:8
# kl:0.02334,lr_multiplier:0.296,loss:2.885922908782959,entropy:2.21378231048584,explained_var_old:0.278,explained_var_new:0.326
# batch i:267, episode_len:11
# kl:0.00849,lr_multiplier:0.444,loss:2.668344736099243,entropy:2.1339688301086426,explained_var_old:0.385,explained_var_new:0.422
# batch i:268, episode_len:14
# kl:0.03034,lr_multiplier:0.444,loss:2.792120933532715,entropy:2.1474251747131348,explained_var_old:0.286,explained_var_new:0.371
# batch i:269, episode_len:10
# kl:0.03053,lr_multiplier:0.444,loss:2.673830986022949,entropy:2.0739026069641113,explained_var_old:0.384,explained_var_new:0.432
# batch i:270, episode_len:10
# kl:0.02124,lr_multiplier:0.444,loss:2.7333693504333496,entropy:2.216575860977173,explained_var_old:0.387,explained_var_new:0.424
# batch i:271, episode_len:11
# kl:0.02782,lr_multiplier:0.444,loss:2.757969379425049,entropy:2.149855613708496,explained_var_old:0.361,explained_var_new:0.425
# batch i:272, episode_len:13
# kl:0.02990,lr_multiplier:0.444,loss:2.740905284881592,entropy:2.1326098442077637,explained_var_old:0.313,explained_var_new:0.372
# batch i:273, episode_len:11
# kl:0.04144,lr_multiplier:0.296,loss:2.7695960998535156,entropy:2.171307325363159,explained_var_old:0.354,explained_var_new:0.403
# batch i:274, episode_len:9
# kl:0.02677,lr_multiplier:0.296,loss:2.690563917160034,entropy:2.044914960861206,explained_var_old:0.309,explained_var_new:0.344
# batch i:275, episode_len:8
# kl:0.01800,lr_multiplier:0.296,loss:2.6923985481262207,entropy:2.168884754180908,explained_var_old:0.403,explained_var_new:0.459
# batch i:276, episode_len:8
# kl:0.02096,lr_multiplier:0.296,loss:2.6650550365448,entropy:2.104586124420166,explained_var_old:0.339,explained_var_new:0.394
# batch i:277, episode_len:13
# kl:0.02477,lr_multiplier:0.296,loss:2.6505794525146484,entropy:1.9880244731903076,explained_var_old:0.336,explained_var_new:0.393
# batch i:278, episode_len:9
# kl:0.01796,lr_multiplier:0.296,loss:2.730855941772461,entropy:2.1501615047454834,explained_var_old:0.352,explained_var_new:0.404
# batch i:279, episode_len:7
# kl:0.01776,lr_multiplier:0.296,loss:2.7628307342529297,entropy:2.191150188446045,explained_var_old:0.318,explained_var_new:0.361
# batch i:280, episode_len:13
# kl:0.01622,lr_multiplier:0.296,loss:2.6770026683807373,entropy:2.076061248779297,explained_var_old:0.335,explained_var_new:0.384
# batch i:281, episode_len:8
# kl:0.02055,lr_multiplier:0.296,loss:2.7205703258514404,entropy:2.077937602996826,explained_var_old:0.350,explained_var_new:0.385
# batch i:282, episode_len:7
# kl:0.02155,lr_multiplier:0.296,loss:2.5389010906219482,entropy:2.0202341079711914,explained_var_old:0.411,explained_var_new:0.471
# batch i:283, episode_len:13
# kl:0.02077,lr_multiplier:0.296,loss:2.641216516494751,entropy:2.0782666206359863,explained_var_old:0.387,explained_var_new:0.408
# batch i:284, episode_len:16
# kl:0.01792,lr_multiplier:0.296,loss:2.7293434143066406,entropy:2.121511459350586,explained_var_old:0.354,explained_var_new:0.398
# batch i:285, episode_len:9
# kl:0.01371,lr_multiplier:0.296,loss:2.701099395751953,entropy:2.082211494445801,explained_var_old:0.365,explained_var_new:0.399
# batch i:286, episode_len:11
# kl:0.01581,lr_multiplier:0.296,loss:2.6393723487854004,entropy:2.071059465408325,explained_var_old:0.380,explained_var_new:0.417
# batch i:287, episode_len:7
# kl:0.01383,lr_multiplier:0.296,loss:2.6153993606567383,entropy:2.0485334396362305,explained_var_old:0.416,explained_var_new:0.463
# batch i:288, episode_len:11
# kl:0.01076,lr_multiplier:0.296,loss:2.5909016132354736,entropy:2.1011507511138916,explained_var_old:0.429,explained_var_new:0.469
# batch i:289, episode_len:7
# kl:0.01035,lr_multiplier:0.296,loss:2.6431403160095215,entropy:2.1409201622009277,explained_var_old:0.418,explained_var_new:0.465
# batch i:290, episode_len:9
# kl:0.01606,lr_multiplier:0.296,loss:2.6978607177734375,entropy:2.0292320251464844,explained_var_old:0.287,explained_var_new:0.347
# batch i:291, episode_len:19
# kl:0.02515,lr_multiplier:0.296,loss:2.646702766418457,entropy:2.0165929794311523,explained_var_old:0.330,explained_var_new:0.383
# batch i:292, episode_len:10
# kl:0.01901,lr_multiplier:0.296,loss:2.717559337615967,entropy:2.1599764823913574,explained_var_old:0.397,explained_var_new:0.423
# batch i:293, episode_len:19
# kl:0.02702,lr_multiplier:0.296,loss:2.658865451812744,entropy:2.130949020385742,explained_var_old:0.367,explained_var_new:0.427
# batch i:294, episode_len:8
# kl:0.02155,lr_multiplier:0.296,loss:2.5860586166381836,entropy:2.0878777503967285,explained_var_old:0.460,explained_var_new:0.487
# batch i:295, episode_len:7
# kl:0.01905,lr_multiplier:0.296,loss:2.623396396636963,entropy:2.0049452781677246,explained_var_old:0.374,explained_var_new:0.411
# batch i:296, episode_len:9
# kl:0.01455,lr_multiplier:0.296,loss:2.592705488204956,entropy:2.041018486022949,explained_var_old:0.389,explained_var_new:0.436
# batch i:297, episode_len:11
# kl:0.01300,lr_multiplier:0.296,loss:2.5296058654785156,entropy:2.074148654937744,explained_var_old:0.465,explained_var_new:0.506
# batch i:298, episode_len:8
# kl:0.01771,lr_multiplier:0.296,loss:2.5666165351867676,entropy:2.0397861003875732,explained_var_old:0.379,explained_var_new:0.429
# batch i:299, episode_len:7
# kl:0.01646,lr_multiplier:0.296,loss:2.4729983806610107,entropy:1.9418985843658447,explained_var_old:0.418,explained_var_new:0.470
# batch i:300, episode_len:14
# kl:0.01421,lr_multiplier:0.296,loss:2.63938570022583,entropy:2.1138722896575928,explained_var_old:0.451,explained_var_new:0.485
# current self-play batch: 300
# num_playouts:2000, win: 10, lose: 0, tie:0
# 发现新的最优策略，进行策略更新
# batch i:301, episode_len:9
# kl:0.01646,lr_multiplier:0.296,loss:2.6028406620025635,entropy:2.108283519744873,explained_var_old:0.346,explained_var_new:0.409
# batch i:302, episode_len:9
# kl:0.01810,lr_multiplier:0.296,loss:2.5455639362335205,entropy:2.065080165863037,explained_var_old:0.495,explained_var_new:0.509
# batch i:303, episode_len:13
# kl:0.02357,lr_multiplier:0.296,loss:2.507986068725586,entropy:1.9746053218841553,explained_var_old:0.429,explained_var_new:0.481
# batch i:304, episode_len:13
# ...
# kl:0.01881,lr_multiplier:0.198,loss:2.4617221355438232,entropy:2.0256412029266357,explained_var_old:0.489,explained_var_new:0.515
# current self-play batch: 400
# num_playouts:3000, win: 6, lose: 4, tie:0
# batch i:401, episode_len:7
# kl:0.01391,lr_multiplier:0.198,loss:2.417997360229492,entropy:1.9558062553405762,explained_var_old:0.466,explained_var_new:0.505
# batch i:402, episode_len:11
# kl:0.01766,lr_multiplier:0.198,loss:2.415163040161133,entropy:1.8743880987167358,explained_var_old:0.395,explained_var_new:0.429
# batch i:403, episode_len:7
# kl:0.01143,lr_multiplier:0.198,loss:2.3963587284088135,entropy:1.8811300992965698,explained_var_old:0.432,explained_var_new:0.487
# batch i:404, episode_len:7
# kl:0.01156,lr_multiplier:0.198,loss:2.4101128578186035,entropy:1.9230968952178955,explained_var_old:0.461,explained_var_new:0.500
# batch i:405, episode_len:8
# kl:0.01851,lr_multiplier:0.198,loss:2.4008724689483643,entropy:1.9147673845291138,explained_var_old:0.451,explained_var_new:0.476
# batch i:406, episode_len:7
# kl:0.00815,lr_multiplier:0.296,loss:2.5053794384002686,entropy:1.9507158994674683,explained_var_old:0.438,explained_var_new:0.469
# batch i:407, episode_len:14
# kl:0.02961,lr_multiplier:0.296,loss:2.4622888565063477,entropy:1.8735530376434326,explained_var_old:0.355,explained_var_new:0.440
# batch i:408, episode_len:7
# kl:0.03219,lr_multiplier:0.296,loss:2.333658456802368,entropy:1.966927409172058,explained_var_old:0.561,explained_var_new:0.616
# batch i:409, episode_len:9
# kl:0.02227,lr_multiplier:0.296,loss:2.4410338401794434,entropy:1.956294059753418,explained_var_old:0.451,explained_var_new:0.500
# batch i:410, episode_len:12
# kl:0.03665,lr_multiplier:0.296,loss:2.378509521484375,entropy:1.9324232339859009,explained_var_old:0.474,explained_var_new:0.529
# batch i:411, episode_len:7
# kl:0.04013,lr_multiplier:0.198,loss:2.3743951320648193,entropy:1.8205528259277344,explained_var_old:0.385,explained_var_new:0.440
# batch i:412, episode_len:9
# kl:0.01709,lr_multiplier:0.198,loss:2.5009355545043945,entropy:1.9771486520767212,explained_var_old:0.428,explained_var_new:0.460
# batch i:413, episode_len:7
# kl:0.01546,lr_multiplier:0.198,loss:2.4684064388275146,entropy:1.9693984985351562,explained_var_old:0.426,explained_var_new:0.471
# batch i:414, episode_len:8
# kl:0.01693,lr_multiplier:0.198,loss:2.325618028640747,entropy:1.8654720783233643,explained_var_old:0.483,explained_var_new:0.511
# batch i:415, episode_len:10
# kl:0.00957,lr_multiplier:0.296,loss:2.3839266300201416,entropy:1.9045816659927368,explained_var_old:0.505,explained_var_new:0.527
# batch i:416, episode_len:11
# kl:0.02586,lr_multiplier:0.296,loss:2.3974666595458984,entropy:1.95613431930542,explained_var_old:0.554,explained_var_new:0.598
# batch i:417, episode_len:10
# kl:0.02069,lr_multiplier:0.296,loss:2.358384370803833,entropy:1.9079744815826416,explained_var_old:0.474,explained_var_new:0.527
# batch i:418, episode_len:7
# kl:0.01504,lr_multiplier:0.296,loss:2.425302743911743,entropy:1.9359323978424072,explained_var_old:0.424,explained_var_new:0.480
# batch i:419, episode_len:9
# kl:0.02325,lr_multiplier:0.296,loss:2.460892915725708,entropy:1.9415874481201172,explained_var_old:0.430,explained_var_new:0.484
# batch i:420, episode_len:9
# kl:0.02216,lr_multiplier:0.296,loss:2.397935628890991,entropy:1.9027529954910278,explained_var_old:0.461,explained_var_new:0.497
# batch i:421, episode_len:20
# kl:0.02195,lr_multiplier:0.296,loss:2.4622445106506348,entropy:1.950877070426941,explained_var_old:0.409,explained_var_new:0.466
# batch i:422, episode_len:9
# kl:0.02649,lr_multiplier:0.296,loss:2.463170051574707,entropy:1.9566545486450195,explained_var_old:0.419,explained_var_new:0.479
# batch i:423, episode_len:9
# kl:0.02132,lr_multiplier:0.296,loss:2.4100327491760254,entropy:1.979876160621643,explained_var_old:0.492,explained_var_new:0.537
# batch i:424, episode_len:9
# kl:0.03385,lr_multiplier:0.296,loss:2.3511362075805664,entropy:1.9146907329559326,explained_var_old:0.437,explained_var_new:0.481
# batch i:425, episode_len:11
# kl:0.03529,lr_multiplier:0.296,loss:2.409053087234497,entropy:1.9674406051635742,explained_var_old:0.497,explained_var_new:0.555
# batch i:426, episode_len:9
# kl:0.02664,lr_multiplier:0.296,loss:2.4438581466674805,entropy:1.9970000982284546,explained_var_old:0.490,explained_var_new:0.529
# batch i:427, episode_len:10
# kl:0.03466,lr_multiplier:0.296,loss:2.3875246047973633,entropy:1.949493408203125,explained_var_old:0.427,explained_var_new:0.487
# batch i:428, episode_len:8
# kl:0.02395,lr_multiplier:0.296,loss:2.3643558025360107,entropy:1.8582284450531006,explained_var_old:0.434,explained_var_new:0.531
# batch i:429, episode_len:9
# kl:0.05043,lr_multiplier:0.198,loss:2.4177470207214355,entropy:1.969550609588623,explained_var_old:0.488,explained_var_new:0.533
# batch i:430, episode_len:11
# kl:0.01421,lr_multiplier:0.198,loss:2.48181414604187,entropy:2.053748846054077,explained_var_old:0.487,explained_var_new:0.519
# batch i:431, episode_len:12
# kl:0.02352,lr_multiplier:0.198,loss:2.365990161895752,entropy:1.8780986070632935,explained_var_old:0.471,explained_var_new:0.507
# batch i:432, episode_len:9
# kl:0.01451,lr_multiplier:0.198,loss:2.405667543411255,entropy:1.9707489013671875,explained_var_old:0.526,explained_var_new:0.565
# batch i:433, episode_len:9
# kl:0.01146,lr_multiplier:0.198,loss:2.5210936069488525,entropy:1.9889781475067139,explained_var_old:0.428,explained_var_new:0.483
# batch i:434, episode_len:14
# kl:0.01335,lr_multiplier:0.198,loss:2.4710988998413086,entropy:1.8789291381835938,explained_var_old:0.387,explained_var_new:0.416
# batch i:435, episode_len:8
# kl:0.01145,lr_multiplier:0.198,loss:2.3227431774139404,entropy:1.835453748703003,explained_var_old:0.483,explained_var_new:0.495
# batch i:436, episode_len:11
# kl:0.01685,lr_multiplier:0.198,loss:2.3943729400634766,entropy:1.9976270198822021,explained_var_old:0.454,explained_var_new:0.495
# batch i:437, episode_len:9
# kl:0.01147,lr_multiplier:0.198,loss:2.4473700523376465,entropy:1.8804969787597656,explained_var_old:0.413,explained_var_new:0.439
# batch i:438, episode_len:9
# kl:0.01553,lr_multiplier:0.198,loss:2.278602123260498,entropy:1.8205162286758423,explained_var_old:0.472,explained_var_new:0.500
# batch i:439, episode_len:13
# kl:0.01575,lr_multiplier:0.198,loss:2.4374778270721436,entropy:1.9340816736221313,explained_var_old:0.442,explained_var_new:0.489
# batch i:440, episode_len:15
# kl:0.01522,lr_multiplier:0.198,loss:2.4200997352600098,entropy:1.980971336364746,explained_var_old:0.443,explained_var_new:0.489
# batch i:441, episode_len:12
# kl:0.01886,lr_multiplier:0.198,loss:2.4189794063568115,entropy:1.8129894733428955,explained_var_old:0.408,explained_var_new:0.444
# batch i:442, episode_len:11
# kl:0.01820,lr_multiplier:0.198,loss:2.424710512161255,entropy:1.948436975479126,explained_var_old:0.464,explained_var_new:0.504
# batch i:443, episode_len:7
# kl:0.01330,lr_multiplier:0.198,loss:2.380258083343506,entropy:1.873580813407898,explained_var_old:0.402,explained_var_new:0.445
# batch i:444, episode_len:7
# kl:0.01398,lr_multiplier:0.198,loss:2.4418087005615234,entropy:1.9110844135284424,explained_var_old:0.393,explained_var_new:0.437
# batch i:445, episode_len:8
# kl:0.01522,lr_multiplier:0.198,loss:2.373746395111084,entropy:1.9000539779663086,explained_var_old:0.400,explained_var_new:0.467
# batch i:446, episode_len:10
# kl:0.01564,lr_multiplier:0.198,loss:2.417269229888916,entropy:1.8796199560165405,explained_var_old:0.455,explained_var_new:0.470
# batch i:447, episode_len:7
# kl:0.01311,lr_multiplier:0.198,loss:2.4027140140533447,entropy:1.888824462890625,explained_var_old:0.462,explained_var_new:0.502
# batch i:448, episode_len:7
# kl:0.01945,lr_multiplier:0.198,loss:2.517813205718994,entropy:1.974416971206665,explained_var_old:0.385,explained_var_new:0.439
# batch i:449, episode_len:12
# kl:0.01411,lr_multiplier:0.198,loss:2.4350507259368896,entropy:1.963434100151062,explained_var_old:0.432,explained_var_new:0.457
# batch i:450, episode_len:14
# kl:0.01579,lr_multiplier:0.198,loss:2.345498561859131,entropy:1.861654281616211,explained_var_old:0.455,explained_var_new:0.518
# current self-play batch: 450
# num_playouts:3000, win: 7, lose: 3, tie:0
# batch i:451, episode_len:14
# kl:0.01492,lr_multiplier:0.198,loss:2.473958969116211,entropy:1.9339805841445923,explained_var_old:0.454,explained_var_new:0.483
# batch i:452, episode_len:7
# kl:0.02229,lr_multiplier:0.198,loss:2.3035624027252197,entropy:1.8232381343841553,explained_var_old:0.505,explained_var_new:0.526
# batch i:453, episode_len:14
# kl:0.01726,lr_multiplier:0.198,loss:2.3479413986206055,entropy:1.841854214668274,explained_var_old:0.431,explained_var_new:0.486
# batch i:454, episode_len:7
# kl:0.02151,lr_multiplier:0.198,loss:2.3172061443328857,entropy:1.889385461807251,explained_var_old:0.501,explained_var_new:0.513
# batch i:455, episode_len:16
# kl:0.01481,lr_multiplier:0.198,loss:2.463242530822754,entropy:1.9618079662322998,explained_var_old:0.394,explained_var_new:0.432
# batch i:456, episode_len:9
# kl:0.01657,lr_multiplier:0.198,loss:2.437791347503662,entropy:1.8806266784667969,explained_var_old:0.403,explained_var_new:0.443
# batch i:457, episode_len:7
# kl:0.01890,lr_multiplier:0.198,loss:2.442033052444458,entropy:1.8860093355178833,explained_var_old:0.401,explained_var_new:0.424
# batch i:458, episode_len:10
# kl:0.01619,lr_multiplier:0.198,loss:2.4569902420043945,entropy:1.9817770719528198,explained_var_old:0.487,explained_var_new:0.506
# batch i:459, episode_len:9
# kl:0.01824,lr_multiplier:0.198,loss:2.352705717086792,entropy:1.87272047996521,explained_var_old:0.430,explained_var_new:0.462
# batch i:460, episode_len:15
# kl:0.01054,lr_multiplier:0.198,loss:2.41752552986145,entropy:1.8269065618515015,explained_var_old:0.366,explained_var_new:0.392
# batch i:461, episode_len:8
# kl:0.01557,lr_multiplier:0.198,loss:2.5519614219665527,entropy:2.0304999351501465,explained_var_old:0.371,explained_var_new:0.406
# batch i:462, episode_len:9
# kl:0.01171,lr_multiplier:0.198,loss:2.405930519104004,entropy:1.8736177682876587,explained_var_old:0.426,explained_var_new:0.461
# batch i:463, episode_len:11
# kl:0.01919,lr_multiplier:0.198,loss:2.4472525119781494,entropy:1.8742109537124634,explained_var_old:0.402,explained_var_new:0.429
# batch i:464, episode_len:7
# kl:0.01471,lr_multiplier:0.198,loss:2.5072338581085205,entropy:1.953941822052002,explained_var_old:0.383,explained_var_new:0.428
# batch i:465, episode_len:9
# kl:0.01138,lr_multiplier:0.198,loss:2.452180862426758,entropy:1.9178043603897095,explained_var_old:0.414,explained_var_new:0.431
# batch i:466, episode_len:8
# kl:0.01893,lr_multiplier:0.198,loss:2.401716947555542,entropy:1.935685396194458,explained_var_old:0.449,explained_var_new:0.475
# batch i:467, episode_len:12
# kl:0.01672,lr_multiplier:0.198,loss:2.4724581241607666,entropy:1.9142884016036987,explained_var_old:0.380,explained_var_new:0.422
# batch i:468, episode_len:11
# kl:0.02008,lr_multiplier:0.198,loss:2.3635878562927246,entropy:1.8693875074386597,explained_var_old:0.496,explained_var_new:0.521
# batch i:469, episode_len:11
# kl:0.01441,lr_multiplier:0.198,loss:2.481311559677124,entropy:2.001919984817505,explained_var_old:0.484,explained_var_new:0.506
# batch i:470, episode_len:16
# kl:0.01782,lr_multiplier:0.198,loss:2.387080192565918,entropy:1.9238886833190918,explained_var_old:0.486,explained_var_new:0.515
# batch i:471, episode_len:7
# kl:0.01114,lr_multiplier:0.198,loss:2.4730682373046875,entropy:1.9665944576263428,explained_var_old:0.421,explained_var_new:0.454
# batch i:472, episode_len:7
# kl:0.01643,lr_multiplier:0.198,loss:2.5019631385803223,entropy:2.009331703186035,explained_var_old:0.405,explained_var_new:0.437
# batch i:473, episode_len:7
# kl:0.01181,lr_multiplier:0.198,loss:2.4453909397125244,entropy:1.9105141162872314,explained_var_old:0.373,explained_var_new:0.406
# batch i:474, episode_len:7
# kl:0.01859,lr_multiplier:0.198,loss:2.3292534351348877,entropy:1.822487235069275,explained_var_old:0.456,explained_var_new:0.499
# batch i:475, episode_len:9
# kl:0.01743,lr_multiplier:0.198,loss:2.440462589263916,entropy:1.9480189085006714,explained_var_old:0.443,explained_var_new:0.461
# batch i:476, episode_len:8
# kl:0.01546,lr_multiplier:0.198,loss:2.488361358642578,entropy:1.9771034717559814,explained_var_old:0.440,explained_var_new:0.469
# batch i:477, episode_len:9
# kl:0.01973,lr_multiplier:0.198,loss:2.437089443206787,entropy:1.8544189929962158,explained_var_old:0.402,explained_var_new:0.443
# batch i:478, episode_len:10
# kl:0.01580,lr_multiplier:0.198,loss:2.4101109504699707,entropy:1.9065430164337158,explained_var_old:0.396,explained_var_new:0.424
# batch i:479, episode_len:7
# kl:0.02279,lr_multiplier:0.198,loss:2.2770321369171143,entropy:1.903085470199585,explained_var_old:0.515,explained_var_new:0.536
# batch i:480, episode_len:7
# kl:0.01899,lr_multiplier:0.198,loss:2.3883790969848633,entropy:1.8606383800506592,explained_var_old:0.428,explained_var_new:0.461
# batch i:481, episode_len:10
# kl:0.02053,lr_multiplier:0.198,loss:2.37774920463562,entropy:1.8604066371917725,explained_var_old:0.476,explained_var_new:0.501
# batch i:482, episode_len:13
# kl:0.01461,lr_multiplier:0.198,loss:2.383133888244629,entropy:1.951871395111084,explained_var_old:0.488,explained_var_new:0.520
# batch i:483, episode_len:9
# kl:0.01379,lr_multiplier:0.198,loss:2.43290114402771,entropy:1.894529104232788,explained_var_old:0.415,explained_var_new:0.441
# batch i:484, episode_len:8
# kl:0.01541,lr_multiplier:0.198,loss:2.4519593715667725,entropy:1.8456823825836182,explained_var_old:0.396,explained_var_new:0.430
# batch i:485, episode_len:12
# kl:0.01991,lr_multiplier:0.198,loss:2.340618133544922,entropy:1.8922243118286133,explained_var_old:0.470,explained_var_new:0.496
# batch i:486, episode_len:10
# kl:0.01531,lr_multiplier:0.198,loss:2.315288782119751,entropy:1.8384571075439453,explained_var_old:0.465,explained_var_new:0.493
# batch i:487, episode_len:7
# kl:0.02271,lr_multiplier:0.198,loss:2.2542810440063477,entropy:1.863082766532898,explained_var_old:0.546,explained_var_new:0.573
# batch i:488, episode_len:9
# kl:0.01236,lr_multiplier:0.198,loss:2.405043125152588,entropy:1.9189324378967285,explained_var_old:0.436,explained_var_new:0.491
# batch i:489, episode_len:8
# kl:0.02036,lr_multiplier:0.198,loss:2.399303913116455,entropy:1.8452081680297852,explained_var_old:0.410,explained_var_new:0.436
# batch i:490, episode_len:13
# kl:0.01753,lr_multiplier:0.198,loss:2.436605930328369,entropy:1.8433899879455566,explained_var_old:0.417,explained_var_new:0.439
# batch i:491, episode_len:7
# kl:0.01257,lr_multiplier:0.198,loss:2.2603681087493896,entropy:1.832363486289978,explained_var_old:0.498,explained_var_new:0.529
# batch i:492, episode_len:7
# kl:0.01783,lr_multiplier:0.198,loss:2.3702967166900635,entropy:1.9531629085540771,explained_var_old:0.505,explained_var_new:0.524
# batch i:493, episode_len:13
# kl:0.01162,lr_multiplier:0.198,loss:2.394601821899414,entropy:1.9137463569641113,explained_var_old:0.476,explained_var_new:0.500
# batch i:494, episode_len:16
# kl:0.02017,lr_multiplier:0.198,loss:2.343743085861206,entropy:1.856933832168579,explained_var_old:0.434,explained_var_new:0.465
# batch i:495, episode_len:7
# kl:0.02498,lr_multiplier:0.198,loss:2.4803194999694824,entropy:1.9157804250717163,explained_var_old:0.366,explained_var_new:0.411
# batch i:496, episode_len:11
# kl:0.02505,lr_multiplier:0.198,loss:2.395749807357788,entropy:1.9021531343460083,explained_var_old:0.461,explained_var_new:0.486
# batch i:497, episode_len:7
# kl:0.02162,lr_multiplier:0.198,loss:2.3836262226104736,entropy:1.898348331451416,explained_var_old:0.470,explained_var_new:0.500
# batch i:498, episode_len:7
# kl:0.01921,lr_multiplier:0.198,loss:2.4226396083831787,entropy:1.9435077905654907,explained_var_old:0.446,explained_var_new:0.476
# batch i:499, episode_len:7
# kl:0.01900,lr_multiplier:0.198,loss:2.3506124019622803,entropy:1.8846373558044434,explained_var_old:0.463,explained_var_new:0.504
# batch i:500, episode_len:7
# kl:0.01792,lr_multiplier:0.198,loss:2.4454522132873535,entropy:1.8534481525421143,explained_var_old:0.427,explained_var_new:0.449
# current self-play batch: 500
# num_playouts:3000, win: 9, lose: 1, tie:0
